# %% [markdown]
# # Chargement des librairies

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from mylib.fonction_exploration import exploration1, exploration2, exploration3, exploration4
from mylib.fonction_pk import test_pk
from mylib.fonction_merge import df_merge
from mylib.fonction_acp import display_circles, display_factorial_planes, display_scree_plot
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats
import seaborn as sns
from pandas_profiling import ProfileReport
import plotly.express as px
from IPython.display import display_html 

from sklearn.cluster import KMeans
from sklearn import decomposition
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn import preprocessing
#from scipy.cluster.hierarchy import dendrogram
from sklearn import metrics
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import AgglomerativeClustering
# to visualize the elbow curve and silhouette scores
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

print("Version numpy : " + np.__version__)
print("Version pandas : " + pd.__version__)

bold = "\033[1m"
red = "\033[31m"
end = "\033[0;0m"

chemin = '../src/df_2010_cleaned.csv'
# Out:
# Version numpy : 1.23.5
# Version pandas : 1.4.4

# %% [markdown]
# # Chargement du fichier nettoyé

# %%
p9 = pd.read_csv(chemin)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # Exploration

# %%
exploration1(p9)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7338" style='display:grid'>
#   <caption>__________ Head __________</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7338_level0_col0" class="col_heading level0 col0" >iso</th>
#       <th id="T_c7338_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_c7338_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_c7338_level0_col3" class="col_heading level0 col3" >Under-nourishment (%)</th>
#       <th id="T_c7338_level0_col4" class="col_heading level0 col4" >HDI</th>
#       <th id="T_c7338_level0_col5" class="col_heading level0 col5" >Peace_index</th>
#       <th id="T_c7338_level0_col6" class="col_heading level0 col6" >Vegetables disponibility (kg/cap/year)</th>
#       <th id="T_c7338_level0_col7" class="col_heading level0 col7" >Enough veg intake (> 91.25 kg/cap/year)</th>
#       <th id="T_c7338_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_c7338_level0_col9" class="col_heading level0 col9" >Exportations</th>
#       <th id="T_c7338_level0_col10" class="col_heading level0 col10" >Importations</th>
#       <th id="T_c7338_level0_col11" class="col_heading level0 col11" >Customs duration (h)</th>
#       <th id="T_c7338_level0_col12" class="col_heading level0 col12" >Customs tax (%)</th>
#       <th id="T_c7338_level0_col13" class="col_heading level0 col13" >Distance (km)</th>
#       <th id="T_c7338_level0_col14" class="col_heading level0 col14" >Gdp/cap</th>
#       <th id="T_c7338_level0_col15" class="col_heading level0 col15" >Population evolution (4y, %)</th>
#       <th id="T_c7338_level0_col16" class="col_heading level0 col16" >Trade balance (exp-imp)</th>
#       <th id="T_c7338_level0_col17" class="col_heading level0 col17" >Self-sufficiency (prod-dispo)</th>
#       <th id="T_c7338_level0_col18" class="col_heading level0 col18" >Market growth (2y, %)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7338_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7338_row0_col0" class="data row0 col0" >AFG</td>
#       <td id="T_c7338_row0_col1" class="data row0 col1" >Afghanistan</td>
#       <td id="T_c7338_row0_col2" class="data row0 col2" >28189672</td>
#       <td id="T_c7338_row0_col3" class="data row0 col3" >21.200000</td>
#       <td id="T_c7338_row0_col4" class="data row0 col4" >0.448000</td>
#       <td id="T_c7338_row0_col5" class="data row0 col5" >3.163000</td>
#       <td id="T_c7338_row0_col6" class="data row0 col6" >54.090000</td>
#       <td id="T_c7338_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_c7338_row0_col8" class="data row0 col8" >2177000000</td>
#       <td id="T_c7338_row0_col9" class="data row0 col9" >176000000</td>
#       <td id="T_c7338_row0_col10" class="data row0 col10" >34000000</td>
#       <td id="T_c7338_row0_col11" class="data row0 col11" >48.000000</td>
#       <td id="T_c7338_row0_col12" class="data row0 col12" >6.950000</td>
#       <td id="T_c7338_row0_col13" class="data row0 col13" >5500.665000</td>
#       <td id="T_c7338_row0_col14" class="data row0 col14" >1771.197985</td>
#       <td id="T_c7338_row0_col15" class="data row0 col15" >10.795637</td>
#       <td id="T_c7338_row0_col16" class="data row0 col16" >142000000</td>
#       <td id="T_c7338_row0_col17" class="data row0 col17" >23.136865</td>
#       <td id="T_c7338_row0_col18" class="data row0 col18" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7338_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7338_row1_col0" class="data row1 col0" >ZAF</td>
#       <td id="T_c7338_row1_col1" class="data row1 col1" >South Africa</td>
#       <td id="T_c7338_row1_col2" class="data row1 col2" >51784921</td>
#       <td id="T_c7338_row1_col3" class="data row1 col3" >3.700000</td>
#       <td id="T_c7338_row1_col4" class="data row1 col4" >0.675000</td>
#       <td id="T_c7338_row1_col5" class="data row1 col5" >2.331000</td>
#       <td id="T_c7338_row1_col6" class="data row1 col6" >180.150000</td>
#       <td id="T_c7338_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_c7338_row1_col8" class="data row1 col8" >17804000000</td>
#       <td id="T_c7338_row1_col9" class="data row1 col9" >1629000000</td>
#       <td id="T_c7338_row1_col10" class="data row1 col10" >386000000</td>
#       <td id="T_c7338_row1_col11" class="data row1 col11" >92.000000</td>
#       <td id="T_c7338_row1_col12" class="data row1 col12" >7.310000</td>
#       <td id="T_c7338_row1_col13" class="data row1 col13" >8769.679000</td>
#       <td id="T_c7338_row1_col14" class="data row1 col14" >12771.910509</td>
#       <td id="T_c7338_row1_col15" class="data row1 col15" >4.633428</td>
#       <td id="T_c7338_row1_col16" class="data row1 col16" >1243000000</td>
#       <td id="T_c7338_row1_col17" class="data row1 col17" >163.656646</td>
#       <td id="T_c7338_row1_col18" class="data row1 col18" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c7338_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7338_row2_col0" class="data row2 col0" >ALB</td>
#       <td id="T_c7338_row2_col1" class="data row2 col1" >Albania</td>
#       <td id="T_c7338_row2_col2" class="data row2 col2" >2913021</td>
#       <td id="T_c7338_row2_col3" class="data row2 col3" >5.800000</td>
#       <td id="T_c7338_row2_col4" class="data row2 col4" >0.754000</td>
#       <td id="T_c7338_row2_col5" class="data row2 col5" >1.881000</td>
#       <td id="T_c7338_row2_col6" class="data row2 col6" >291.200000</td>
#       <td id="T_c7338_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_c7338_row2_col8" class="data row2 col8" >1465000000</td>
#       <td id="T_c7338_row2_col9" class="data row2 col9" >34000000</td>
#       <td id="T_c7338_row2_col10" class="data row2 col10" >126000000</td>
#       <td id="T_c7338_row2_col11" class="data row2 col11" >14.000000</td>
#       <td id="T_c7338_row2_col12" class="data row2 col12" >5.780000</td>
#       <td id="T_c7338_row2_col13" class="data row2 col13" >1499.451000</td>
#       <td id="T_c7338_row2_col14" class="data row2 col14" >9627.765729</td>
#       <td id="T_c7338_row2_col15" class="data row2 col15" >-2.657469</td>
#       <td id="T_c7338_row2_col16" class="data row2 col16" >-92000000</td>
#       <td id="T_c7338_row2_col17" class="data row2 col17" >211.714328</td>
#       <td id="T_c7338_row2_col18" class="data row2 col18" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_6a498" style='display:grid'>
#   <caption>__________ Tail __________</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a498_level0_col0" class="col_heading level0 col0" >iso</th>
#       <th id="T_6a498_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_6a498_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_6a498_level0_col3" class="col_heading level0 col3" >Under-nourishment (%)</th>
#       <th id="T_6a498_level0_col4" class="col_heading level0 col4" >HDI</th>
#       <th id="T_6a498_level0_col5" class="col_heading level0 col5" >Peace_index</th>
#       <th id="T_6a498_level0_col6" class="col_heading level0 col6" >Vegetables disponibility (kg/cap/year)</th>
#       <th id="T_6a498_level0_col7" class="col_heading level0 col7" >Enough veg intake (> 91.25 kg/cap/year)</th>
#       <th id="T_6a498_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_6a498_level0_col9" class="col_heading level0 col9" >Exportations</th>
#       <th id="T_6a498_level0_col10" class="col_heading level0 col10" >Importations</th>
#       <th id="T_6a498_level0_col11" class="col_heading level0 col11" >Customs duration (h)</th>
#       <th id="T_6a498_level0_col12" class="col_heading level0 col12" >Customs tax (%)</th>
#       <th id="T_6a498_level0_col13" class="col_heading level0 col13" >Distance (km)</th>
#       <th id="T_6a498_level0_col14" class="col_heading level0 col14" >Gdp/cap</th>
#       <th id="T_6a498_level0_col15" class="col_heading level0 col15" >Population evolu

# %%
exploration2(p9)
# Out:
#                                         Nombre de valeurs totales  \
# iso                                                           145
# Country                                                       145
# Population                                                    145
# Under-nourishment (%)                                         145
# HDI                                                           145
# Peace_index                                                   145
# Vegetables disponibility (kg/cap/year)                        145
# Enough veg intake (> 91.25 kg/cap/year)                       145
# Production                                                    145
# Exportations                                                  145
# Importations                                                  145
# Customs duration (h)                                          145
# Customs tax (%)                                               145
# Distance (km)                                                 145
# Gdp/cap                                                       145
# Population evolution (4y, %)                                  145
# Trade balance (exp-imp)                                       145
# Self-sufficiency (prod-dispo)                                 145
# Market growth (2y, %)                                         145
#
#                                         Type des données Nombre de NaN  \
# iso                                               object             0
# Country                                           object             0
# Population                                         int64             0
# Under-nourishment (%)                            float64             0
# HDI                                              float64             0
# Peace_index                                      float64             0
# Vegetables disponibility (kg/cap/year)           float64             0
# Enough veg intake (> 91.25 kg/cap/year)            int64             0
# Production                                         int64             0
# Exportations                                       int64             0
# Importations                                       int64             0
# Customs duration (h)                             float64             0
# Customs tax (%)                                  float64             0
# Distance (km)                                    float64             0
# Gdp/cap                                          float64             0
# Population evolution (4y, %)                     float64             0
# Trade balance (exp-imp)                            int64             0
# Self-sufficiency (prod-dispo)                    float64             0
# Market growth (2y, %)                            float64             0
#
#                                         NaN en % Nombre de valeurs uniques  \
# iso                                         0.00                       145
# Country                                     0.00                       145
# Population                                  0.00                       145
# Under-nourishment (%)                       0.00                        79
# HDI                                         0.00                       122
# Peace_index                                 0.00                       138
# Vegetables disponibility (kg/cap/year)      0.00                       141
# Enough veg intake (> 91.25 kg/cap/year)     0.00                         2
# Production                                  0.00                       142
# Exportations                                0.00                       110
# Importations                                0.00                       133
# Customs duration (h)                        0.00                        98
# Customs tax (%)                             0.00                       117
# Distance (km)                               0.00                       145
# Gdp/cap                                     0.00                       145
# Population evolution (4y, %)                0.00                       145
# Trade balance (exp-imp)                     0.00                       138
# Self-sufficiency (prod-dispo)               0.00                       145
# Market growth (2y, %)                       0.00                         1
#
#                                         Valeurs uniques en%
# iso                                                  100.00
# Country                                              100.00
# Population                                           100.00
# Under-nourishment (%)                                 54.48
# HDI                                                   84.14
# Peace_index                                           95.17
# Vegetables disponibility (kg/cap/year)                97.24
# Enough veg intake (> 91.25 kg/cap/year)                1.38
# Production                                            97.93
# Exportations                                          75.86
# Importations                                          91.72
# Customs duration (h)                                  67.59
# Customs tax (%)                                       80.69
# Distance (km)                                        100.00
# Gdp/cap                                              100.00
# Population evolution (4y, %)                         100.00
# Trade balance (exp-imp)                               95.17
# Self-sufficiency (prod-dispo)                        100.00
# Market growth (2y, %)                                  0.69

# %%
exploration3(p9)
# Out:
# ---------------------------------------
# Nombre de lignes et de colonnes (shape)
# ---------------------------------------
#
# (145, 19)
#
# --------------------------------------
# Affichage des NaN (isna().any(axis=1))
# --------------------------------------
#
# Empty DataFrame
# Columns: [iso, Country, Population, Under-nourishment (%), HDI, Peace_index, Vegetables disponibility (kg/cap/year), Enough veg intake (> 91.25 kg/cap/year), Production, Exportations, Importations, Customs duration (h), Customs tax (%), Distance (km), Gdp/cap, Population evolution (4y, %), Trade balance (exp-imp), Self-sufficiency (prod-dispo), Market growth (2y, %)]
# Index: []
#
# ---------------------------------------
# Nombre de doublons (duplicated().sum())
# ---------------------------------------
#
# 0
#
# -----------------------------------------------------
# Affichage des doublons (df[df.duplicated()].head(10))
# -----------------------------------------------------
#
# Empty DataFrame
# Columns: [iso, Country, Population, Under-nourishment (%), HDI, Peace_index, Vegetables disponibility (kg/cap/year), Enough veg intake (> 91.25 kg/cap/year), Production, Exportations, Importations, Customs duration (h), Customs tax (%), Distance (km), Gdp/cap, Population evolution (4y, %), Trade balance (exp-imp), Self-sufficiency (prod-dispo), Market growth (2y, %)]
# Index: []

# %%
exploration4(p9)
# Out:
#                                          count unique          top freq  \
# iso                                        145    145          AFG    1
# Country                                    145    145  Afghanistan    1
# Population                              145.00    NaN          NaN  NaN
# Under-nourishment (%)                   145.00    NaN          NaN  NaN
# HDI                                     145.00    NaN          NaN  NaN
# Peace_index                             145.00    NaN          NaN  NaN
# Vegetables disponibility (kg/cap/year)  145.00    NaN          NaN  NaN
# Enough veg intake (> 91.25 kg/cap/year) 145.00    NaN          NaN  NaN
# Production                              145.00    NaN          NaN  NaN
# Exportations                            145.00    NaN          NaN  NaN
# Importations                            145.00    NaN          NaN  NaN
# Customs duration (h)                    145.00    NaN          NaN  NaN
# Customs tax (%)                         145.00    NaN          NaN  NaN
# Distance (km)                           145.00    NaN          NaN  NaN
# Gdp/cap                                 145.00    NaN          NaN  NaN
# Population evolution (4y, %)            145.00    NaN          NaN  NaN
# Trade balance (exp-imp)                 145.00    NaN          NaN  NaN
# Self-sufficiency (prod-dispo)           145.00    NaN          NaN  NaN
# Market growth (2y, %)                   145.00    NaN          NaN  NaN
#
#                                                   mean            std  \
# iso                                                NaN            NaN
# Country                                            NaN            NaN
# Population                                 46501490.37   154931842.18
# Under-nourishment (%)                            10.14           9.31
# HDI                                               0.69           0.16
# Peace_index                                       2.04           0.43
# Vegetables disponibility (kg/cap/year)          190.31          91.39
# Enough veg intake (> 91.25 kg/cap/year)           0.88           0.32
# Production                              18512572413.79 79986100593.65
# Exportations                             1667979310.34  5826637101.22
# Importations                             1530544827.59  3541569643.73
# Customs duration (h)                             60.41          63.32
# Customs tax (%)                                   7.85           4.83
# Distance (km)                                  5498.44        3581.42
# Gdp/cap                                       15602.86       15444.45
# Population evolution (4y, %)                      6.32           7.73
# Trade balance (exp-imp)                   137434482.76  5358745957.17
# Self-sufficiency (prod-dispo)                   133.60         209.63
# Market growth (2y, %)                             0.00           0.00
#
#                                                     min           25%  \
# iso                                                 NaN           NaN
# Country                                             NaN           NaN
# Population                                    318041.00    4560155.00
# Under-nourishment (%)                              2.50          2.50
# HDI                                                0.34          0.54
# Peace_index                                        1.13          1.76
# Vegetables disponibility (kg/cap/year)            42.46        128.07
# Enough veg intake (> 91.25 kg/cap/year)            0.00          1.00
# Production                                  20000000.00 1016000000.00
# Exportations                                       0.00   13000000.00
# Importations                                 6000000.00   87000000.00
# Customs duration (h)                               0.00         13.00
# Customs tax (%)                                    0.50          3.28
# Distance (km)                                    408.96       2077.50
# Gdp/cap                                          616.53       3719.20
# Population evolution (4y, %)                      -6.09          2.08
# Trade balance (exp-imp)                 -19320000000.00 -403000000.00
# Self-sufficiency (prod-dispo)                   -111.41          5.93
# Market growth (2y, %)                              0.00          0.00
#
#                                                   50%            75%  \
# iso                                               NaN            NaN
# Country                                           NaN            NaN
# Population                                10474410.00    32341728.00
# Under-nourishment (%)                            6.10          15.20
# HDI                                              0.72           0.82
# Peace_index                                      2.03           2.26
# Vegetables disponibility (kg/cap/year)         169.15         244.26
# Enough veg intake (> 91.25 kg/cap/year)          1.00           1.00
# Production                              2769000000.00 10646000000.00
# Exportations                             123000000.00   682000000.00
# Importations                             331000000.00  1024000000.00
# Customs duration (h)                            48.00          88.33
# Customs tax (%)                                  7.13          11.59
# Distance (km)                                 5147.52        8431.75
# Gdp/cap                                       9664.27       20890.82
# Population evolution (4y, %)                     5.29           9.44
# Trade balance (exp-imp)                  -93000000.00    40000000.00
# Self-sufficiency (prod-dispo)                   61.72         171.53
# Market growth (2y, %)                            0.00           0.00
#
#                                                     max
# iso                                                 NaN
# Country                                             NaN
# Population                                1337705000.00
# Under-nourishment (%)                             44.40
# HDI                                                0.94
# Peace_index                                        3.16
# Vegetables disponibility (kg/cap/year)           487.57
# Enough veg intake (> 91.25 kg/cap/year)            1.00
# Production                              860012000000.00
# Exportations                             59798000000.00
# Importations                             30171000000.00
# Customs duration (h)                             347.04
# Customs tax (%)                                   20.53
# Distance (km)                                  18894.29
# Gdp/cap                                        75193.71
# Population evolution (4y, %)                      73.13
# Trade balance (exp-imp)                  48529000000.00
# Self-sufficiency (prod-dispo)                   1126.13
# Market growth (2y, %)                              0.00

# %%
p9.sample()
# Out:
#      iso  Country  Population  Under-nourishment (%)  HDI  Peace_index  \
# 133  UKR  Ukraine    45870741                   2.50 0.76         2.22
#
#      Vegetables disponibility (kg/cap/year)  \
# 133                                  301.96
#
#      Enough veg intake (> 91.25 kg/cap/year)   Production  Exportations  \
# 133                                        1  40706000000    3259000000
#
#      Importations  Customs duration (h)  Customs tax (%)  Distance (km)  \
# 133     331000000                  6.00             4.50        2275.21
#
#      Gdp/cap  Population evolution (4y, %)  Trade balance (exp-imp)  \
# 133  8559.93                         -1.96               2928000000
#
#      Self-sufficiency (prod-dispo)  Market growth (2y, %)
# 133                         585.45                   0.00

# %% [markdown]
# # Vérification des outliers en prévision de l'ACP

# %%
# on détermine les colonnes numériques
num = []
for i in p9.columns:
    if p9[i].dtypes == int or p9[i].dtypes == float:
        num.append(i)

# %% [markdown]
# ## Z-score

# %%
# on calcule le z-score sur toutes les variables numériques
for i in num:
    p9.sort_values(by=i, inplace=True)
    outlier_z = p9[stats.zscore(p9[i]) > 1.96]
    nb_outlier_z = len(outlier_z)
    print(bold + f"\n{i} : {nb_outlier_z} outliers \n\n" + end + f"{outlier_z[['Country', i]]} \n" + "-" * 50)
# Out:
# Population : 2 outliers
#
#    Country  Population
# 53   India  1240613620
# 26   China  1337705000
# --------------------------------------------------
#
# Under-nourishment (%) : 10 outliers
#
#                       Country  Under-nourishment (%)
# 86                    Namibia                  28.80
# 116              Sierra Leone                  29.10
# 108  Central African Republic                  30.30
# 127               Timor-Leste                  31.20
# 124                      Chad                  31.40
# 107                    Rwanda                  31.40
# 112          Congo, Dem. Rep.                  34.20
# 71                    Liberia                  34.50
# 29                Congo, Rep.                  36.50
# 50                      Haiti                  44.40
# --------------------------------------------------
#
# HDI : 0 outliers
#
# Empty DataFrame
# Columns: [Country, HDI]
# Index: []
# --------------------------------------------------
#
# Peace_index : 7 outliers
#
#                 Country  Peace_index
# 58               Israel         2.99
# 112    Congo, Dem. Rep.         3.03
# 124                Chad         3.05
# 41   Russian Federation         3.10
# 49              Georgia         3.13
# 96             Pakistan         3.14
# 0           Afghanistan         3.16
# --------------------------------------------------
#
# Vegetables disponibility (kg/cap/year) : 7 outliers
#
#               Country  Vegetables disponibility (kg/cap/year)
# 26              China                                  390.77
# 5              Angola                                  391.18
# 20            Belarus                                  392.86
# 107            Rwanda                                  400.02
# 76             Malawi                                  421.02
# 44              Ghana                                  433.71
# 112  Congo, Dem. Rep.                                  487.57
# --------------------------------------------------
#
# Enough veg intake (> 91.25 kg/cap/year) : 0 outliers
#
# Empty DataFrame
# Columns: [Country, Enough veg intake (> 91.25 kg/cap/year)]
# Index: []
# --------------------------------------------------
#
# Production : 3 outliers
#
#            Country    Production
# 53           India  185348000000
# 143  United States  391421000000
# 26           China  860012000000
# --------------------------------------------------
#
# Exportations : 4 outliers
#
#            Country  Exportations
# 26           China   14420000000
# 7        Argentina   18768000000
# 126       Thailand   19338000000
# 143  United States   59798000000
# --------------------------------------------------
#
# Importations : 6 outliers
#
#            Country  Importations
# 4          Germany    8456000000
# 81          Mexico    8868000000
# 109    Korea, Rep.    9976000000
# 143  United States   11269000000
# 61           Japan   19332000000
# 26           China   30171000000
# --------------------------------------------------
#
# Customs duration (h) : 7 outliers
#
#               Country  Customs duration (h)
# 71            Liberia                193.00
# 23           Cameroon                202.00
# 32      Cote d'Ivoire                238.71
# 29        Congo, Rep.                276.00
# 135     Venezuela, RB                288.00
# 5              Angola                312.00
# 112  Congo, Dem. Rep.                347.04
# --------------------------------------------------
#
# Customs tax (%) : 9 outliers
#
#                       Country  Customs tax (%)
# 108  Central African Republic            17.39
# 124                      Chad            17.42
# 130                   Tunisia            18.13
# 144                  Ethiopia            18.19
# 29                Congo, Rep.            18.20
# 42                      Gabon            18.51
# 23                   Cameroon            18.72
# 34                   Djibouti            18.79
# 55         Iran, Islamic Rep.            20.53
# --------------------------------------------------
#
# Distance (km) : 4 outliers
#
#               Country  Distance (km)
# 127       Timor-Leste       13175.21
# 98   Papua New Guinea       14488.95
# 9           Australia       16513.02
# 91        New Zealand       18894.29
# --------------------------------------------------
#
# Gdp/cap : 7 outliers
#
#                   Country  Gdp/cap
# 6            Saudi Arabia 48047.79
# 143         United States 48650.64
# 93                   Oman 53255.61
# 120           Switzerland 54858.45
# 90                 Norway 57919.65
# 141  United Arab Emirates 65411.94
# 66                 Kuwait 75193.71
# --------------------------------------------------
#
# Population evolution (4y, %) : 2 outliers
#
#                   Country  Population evolution (4y, %)
# 66                 Kuwait                         24.54
# 141  United Arab Emirates                         73.13
# --------------------------------------------------
#
# Trade balance (exp-imp) : 3 outliers
#
#            Country  Trade balance (exp-imp)
# 126       Thailand              18046000000
# 7        Argentina              18543000000
# 143  United States              48529000000
# --------------------------------------------------
#
# Self-sufficiency (prod-dispo) : 8 outliers
#
#            Country  Self-sufficiency (prod-dispo)
# 100    Netherlands                         561.44
# 133        Ukraine                         585.45
# 7        Argentina                         603.39
# 52         Hungary                         748.67
# 20         Belarus                         765.43
# 99        Paraguay                         790.70
# 143  United States                        1075.72
# 115         Serbia                        1126.13
# --------------------------------------------------
#
# Market growth (2y, %) : 0 outliers
#
# Empty DataFrame
# Columns: [Country, Market growth (2y, %)]
# Index: []
# --------------------------------------------------

# %% [markdown]
# ## Log

# %%
p9_log = p9.copy()
p9_log = p9_log.set_index(['Country'])
p9_log = p9_log[num]
p9_log.sample()
# Out:
#              Population  Under-nourishment (%)  HDI  Peace_index  \
# Country
# Gambia, The     1937275                  10.40 0.46         1.96
#
#              Vegetables disponibility (kg/cap/year)  \
# Country
# Gambia, The                                   50.40
#
#              Enough veg intake (> 91.25 kg/cap/year)  Production  \
# Country
# Gambia, The                                        0    89000000
#
#              Exportations  Importations  Customs duration (h)  \
# Country
# Gambia, The             0      38000000                109.33
#
#              Customs tax (%)  Distance (km)  Gdp/cap  \
# Country
# Gambia, The            15.54        4129.96  2254.05
#
#              Population evolution (4y, %)  Trade balance (exp-imp)  \
# Country
# Gambia, The                         13.21                -38000000
#
#              Self-sufficiency (prod-dispo)  Market growth (2y, %)
# Country
# Gambia, The                          -4.46                   0.00

# %% [markdown]
# ### Graphiques de distribution

# %%
f, a = plt.subplots(6, 3, figsize=(20,40))
a = a.flatten()
for i, col in enumerate(p9_log.columns):
    sns.distplot(p9_log[col], ax=a[i], kde= True).set_title('Skew: {:.2f}'.format(p9_log[col].skew()))
plt.show()

# %% [raw]
# #Plot a Histogram of the data
# #fig, axes = plt.subplots(5, 3, figsize=(25, 20))
# for i in p9_log.columns:
#     ax = sns.distplot(p9_log[i], kde=True)
# #ax.set(xlabel= ‘Garage Area (ft²)’, ylabel=’Counts’, title=’Frequency of Garage Sizes (ft²)’)
#     plt.show()

# %% [markdown]
# ### Calcul de Skew et Kurtosis

# %%
#Calculating Skew and Kurtosis 
for i in p9_log.columns:
    kurtosis = round((stats.kurtosis(p9_log[i])), ndigits=2)
    skew = round((stats.skew(p9_log[i])), ndigits=2)
    #print("\nkurtosis :", i, kurtosis) 
    #print("skew", i, skew, "\n")
    print("\n" + "-" * 50 + bold + f"\n{i} : kurtosis {kurtosis}" + end)
    print(bold + f"{i} : skew {skew} \n" + end)
#Interpreting Kurtosis
    if  -0.5 < kurtosis < 0.5:
        print (f'A kurtosis of {kurtosis} means the distribution is approximately normal sometimes called mesokurtic distributions')
    elif kurtosis <= -0.5: 
        print (f'A kurtosis of {kurtosis} means the distribution is light-tailed (negative) sometimes called a platykurtic distributions')
    elif kurtosis >= 0.5:
        print (f'A kurtosis of {kurtosis} means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution')
#Interpreting Skewness
    if -0.5 < skew < 0.5:
        print (f'A skew of {skew} means the distribution is approx. symmetric')
    elif  -1 < skew < -0.5 or 0.5 < skew < 1.0:
        print (f'A skew of {skew} means the distribution is moderately skewed')
    else:
        print (f'A skew of {skew} means the distribution is highly skewed')
# Out:
# --------------------------------------------------
# Population : kurtosis 55.51
# Population : skew 7.28
#
# A kurtosis of 55.51 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 7.28 means the distribution is highly skewed
#
# --------------------------------------------------
# Under-nourishment (%) : kurtosis 1.04
# Under-nourishment (%) : skew 1.32
#
# A kurtosis of 1.04 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.32 means the distribution is highly skewed
#
# --------------------------------------------------
# HDI : kurtosis -1.06
# HDI : skew -0.29
#
# A kurtosis of -1.06 means the distribution is light-tailed (negative) sometimes called a platykurtic distributions
# A skew of -0.29 means the distribution is approx. symmetric
#
# --------------------------------------------------
# Peace_index : kurtosis 0.17
# Peace_index : skew 0.45
#
# A kurtosis of 0.17 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.45 means the distribution is approx. symmetric
#
# --------------------------------------------------
# Vegetables disponibility (kg/cap/year) : kurtosis 0.23
# Vegetables disponibility (kg/cap/year) : skew 0.8
#
# A kurtosis of 0.23 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.8 means the distribution is moderately skewed
#
# --------------------------------------------------
# Enough veg intake (> 91.25 kg/cap/year) : kurtosis 3.66
# Enough veg intake (> 91.25 kg/cap/year) : skew -2.38
#
# A kurtosis of 3.66 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of -2.38 means the distribution is highly skewed
#
# --------------------------------------------------
# Production : kurtosis 86.12
# Production : skew 8.9
#
# A kurtosis of 86.12 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 8.9 means the distribution is highly skewed
#
# --------------------------------------------------
# Exportations : kurtosis 67.76
# Exportations : skew 7.48
#
# A kurtosis of 67.76 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 7.48 means the distribution is highly skewed
#
# --------------------------------------------------
# Importations : kurtosis 32.45
# Importations : skew 5.04
#
# A kurtosis of 32.45 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 5.04 means the distribution is highly skewed
#
# --------------------------------------------------
# Customs duration (h) : kurtosis 4.97
# Customs duration (h) : skew 1.94
#
# A kurtosis of 4.97 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.94 means the distribution is highly skewed
#
# --------------------------------------------------
# Customs tax (%) : kurtosis -0.61
# Customs tax (%) : skew 0.64
#
# A kurtosis of -0.61 means the distribution is light-tailed (negative) sometimes called a platykurtic distributions
# A skew of 0.64 means the distribution is moderately skewed
#
# --------------------------------------------------
# Distance (km) : kurtosis 0.46
# Distance (km) : skew 0.68
#
# A kurtosis of 0.46 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.68 means the distribution is moderately skewed
#
# --------------------------------------------------
# Gdp/cap : kurtosis 1.45
# Gdp/cap : skew 1.37
#
# A kurtosis of 1.45 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.37 means the distribution is highly skewed
#
# --------------------------------------------------
# Population evolution (4y, %) : kurtosis 36.66
# Population evolution (4y, %) : skew 4.51
#
# A kurtosis of 36.66 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 4.51 means the distribution is highly skewed
#
# --------------------------------------------------
# Trade balance (exp-imp) : kurtosis 47.29
# Trade balance (exp-imp) : skew 5.14
#
# A kurtosis of 47.29 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 5.14 means the distribution is highly skewed
#
# --------------------------------------------------
# Self-sufficiency (prod-dispo) : kurtosis 6.11
# Self-sufficiency (prod-dispo) : skew 2.28
#
# A kurtosis of 6.11 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 2.28 means the distribution is highly skewed
#
# --------------------------------------------------
# Market growth (2y, %) : kurtosis nan
# Market growth (2y, %) : skew nan
#
# A skew of nan means the distribution is highly skewed

# %% [markdown]
# ### Test de normalité

# %%
# calculate
for i in p9_log.columns:
    stat, p = stats.normaltest(p9_log[i])
    print (bold + f'{i}' + end + f': \nStatistic={stat}, p={p}')
   # print ('--'*25) 

# interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
        print ('--'*25) 
    else:
        print('Sample does not look Gaussian (reject H0)')
        print ('--'*25)
# Out:
# Population:
# Statistic=236.97962151496623, p=3.471594776701607e-52
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Under-nourishment (%):
# Statistic=33.91671713242007, p=4.3159703506770864e-08
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# HDI:
# Statistic=31.92493998836144, p=1.168388742807832e-07
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Peace_index:
# Statistic=5.432504297266935, p=0.06612210644456609
# Sample looks Gaussian (fail to reject H0)
# --------------------------------------------------
# Vegetables disponibility (kg/cap/year):
# Statistic=14.203645822173037, p=0.0008236022004349256
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Enough veg intake (> 91.25 kg/cap/year):
# Statistic=78.94086160869695, p=7.214557570418701e-18
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Production:
# Statistic=269.2286071903613, p=3.449457221166935e-59
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Exportations:
# Statistic=244.08058112481422, p=9.967247416762742e-54
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Importations:
# Statistic=186.4757297187574, p=3.215953696559763e-41
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Customs duration (h):
# Statistic=71.7750881547891, p=2.5955992388282163e-16
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Customs tax (%):
# Statistic=12.967495452002394, p=0.001528073135247736
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Distance (km):
# Statistic=12.034036485531267, p=0.0024369250916057494
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Gdp/cap:
# Statistic=37.95153805015096, p=5.740215836894366e-09
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Population evolution (4y, %):
# Statistic=178.56619862993352, p=1.6781958403299933e-39
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Trade balance (exp-imp):
# Statistic=196.4045879043366, p=2.2453581630486172e-43
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Self-sufficiency (prod-dispo):
# Statistic=85.4267611908963, p=2.817179399440053e-19
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Market growth (2y, %):
# Statistic=nan, p=nan
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------

# %%
#pip install outliers

# %%
#import numpy as np
#from OUTLIERS import smirnov_grubbs as grubbs

#grubbs.max_test(p9.Population, alpha=.01)

# %% [markdown]
# ### Mise en log des colonnes éligibles

# %%
p9.columns
# Out:
# Index(['iso', 'Country', 'Population', 'Under-nourishment (%)', 'HDI',
#        'Peace_index', 'Vegetables disponibility (kg/cap/year)',
#        'Enough veg intake (> 91.25 kg/cap/year)', 'Production', 'Exportations',
#        'Importations', 'Customs duration (h)', 'Customs tax (%)',
#        'Distance (km)', 'Gdp/cap', 'Population evolution (4y, %)',
#        'Trade balance (exp-imp)', 'Self-sufficiency (prod-dispo)',
#        'Market growth (2y, %)'],
#       dtype='object')

# %%
# Data varies in several magnitudes and has both positive, zero and negative numbers  
# log modulus transform 
log_columns = ['Population', 'Under-nourishment (%)', 'Vegetables disponibility (kg/cap/year)',
              'Production', 'Exportations', 'Importations', 'Customs duration (h)', 'Customs tax (%)',
               'Distance (km)', 'Gdp/cap', 'Trade balance (exp-imp)', 'Population evolution (4y, %)',
               'Self-sufficiency (prod-dispo)']
for i in log_columns:
    p9_log[i] = np.sign(p9_log[i])*(np.log10(np.abs(p9_log[i])+1))
    
p9_log
# Out:
#            Population  Under-nourishment (%)  HDI  Peace_index  \
# Country
# Lesotho          6.31                   1.10 0.47         1.92
# Jordan           6.84                   0.86 0.72         1.94
# Bolivia          7.01                   1.33 0.66         2.12
# Gabon            6.23                   1.20 0.66         2.08
# Australia        7.34                   0.54 0.92         1.36
# ...               ...                    ...  ...          ...
# Nicaragua        6.77                   1.32 0.61         1.88
# Georgia          6.58                   0.89 0.76         3.13
# India            9.09                   1.23 0.57         2.68
# Indonesia        8.39                   1.15 0.66         1.81
# Serbia           6.86                   0.54 0.77         2.10
#
#            Vegetables disponibility (kg/cap/year)  \
# Country
# Lesotho                                      2.40
# Jordan                                       2.18
# Bolivia                                      2.19
# Gabon                                        2.29
# Australia                                    2.23
# ...                                           ...
# Nicaragua                                    2.03
# Georgia                                      2.12
# India                                        2.10
# Indonesia                                    2.23
# Serbia                                       2.29
#
#            Enough veg intake (> 91.25 kg/cap/year)  Production  Exportations  \
# Country
# Lesotho                                          1        8.44          0.00
# Jordan                                           1        9.26          8.89
# Bolivia                                          1        9.44          8.22
# Gabon                                            1        8.73          0.00
# Australia                                        1        9.80          9.11
# ...                                            ...         ...           ...
# Nicaragua                                        1        8.88          7.95
# Georgia                                          1        8.77          7.51
# India                                            1       11.27          9.70
# Indonesia                                        1       10.74          8.95
# Serbia                                           1        9.98          9.27
#
#            Importations  Customs duration (h)  Customs tax (%)  Distance (km)  \
# Country
# Lesotho            8.48                  0.70             1.07           3.95
# Jordan             8.89                  1.75             1.10           3.51
# Bolivia            7.95                  1.69             1.03           4.00
# Gabon              7.40                  1.99             1.29           3.72
# Australia          8.65                  1.56             0.59           4.22
# ...                 ...                   ...              ...            ...
# Nicaragua          8.29                  1.79             0.71           3.95
# Georgia            7.99                  0.85             0.18           3.51
# India              9.37                  2.04             0.99           3.85
# Indonesia          9.63                  1.80             0.79           4.06
# Serbia             8.08                  0.67             0.75           3.16
#
#            Gdp/cap  Population evolution (4y, %)  Trade balance (exp-imp)  \
# Country
# Lesotho       3.33                          0.52                    -8.48
# Jordan        4.00                          1.18                    -6.90
# Bolivia       3.71                          0.91                     7.89
# Gabon         4.15                          1.17                    -7.40
# Australia     4.60                          0.94                     8.92
# ...            ...                           ...                      ...
# Nicaragua     3.60                          0.84                    -8.03
# Georgia       3.88                         -0.53                    -7.82
# India         3.62                          0.83                     9.43
# Indonesia     3.93                          0.80                    -9.52
# Serbia        4.11                         -0.42                     9.24
#
#            Self-sufficiency (prod-dispo)  Market growth (2y, %)
# Country
# Lesotho                            -2.05                   0.00
# Jordan                              2.05                   0.00
# Bolivia                             2.06                   0.00
# Gabon                               2.07                   0.00
# Australia                           2.08                   0.00
# ...                                  ...                    ...
# Nicaragua                           1.39                   0.00
# Georgia                             1.42                   0.00
# India                               1.43                   0.00
# Indonesia                           1.78                   0.00
# Serbia                              3.05                   0.00
#
# [145 rows x 17 columns]

# %% [markdown]
# ## **Boxplots**

# %%
# création boxplots
fig=plt.figure(figsize=(25,15))
p9_log.boxplot(vert=False)
plt.yticks(size=20)
plt.show()

# %%
#pd.options.display.max_rows = None

# %% [markdown]
# # Vérification des corrélations

# %% [markdown]
# <span style="color:red">**Les distributions des variables n'étant pas toutes normales, nous allons utiliser le test de Spearman pour avoir un aperçu des corrélations**</span>

# %% [markdown]
# ## Corrélation de Spearman

# %%
corr = p9_log.corr(method='spearman')
#corr

# %%
plt.figure(figsize=(20,20))
sns.heatmap(p9_log.corr(method='spearman'), annot=True, annot_kws={"size": 14}, fmt=".2f")
plt.xticks(size=15)
plt.yticks(size=15)
plt.title("\nCorrelations on all numeric features\n", size=30, fontweight='bold' )
plt.show()

# %%
# Beaucoup d'informations, on va visualiser les corrélations les plus élevées
plt.figure(figsize=(20, 20))
sns.heatmap(np.round(corr, 2)[(corr >= 0.4) | (corr <= -0.4)], 
            vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 15}, square=True)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title("\nHighest correlations\n", size=25, fontweight='bold' );

# %% [markdown]
# # Visionnage du DataFrame final (log) avant analyse

# %%
cell_hover = {
    "selector": "td:hover",
    "props": [("background-color", "#FFFFE0")]
}
index_names = {
    "selector": ".index_name",
    "props": "background-color: #DC7633; font-style: italic; color: white; font-weight:normal;"
}
headers = {
    "selector": "th:not(.index_name)",
    "props": "background-color: #DC7633; color: white; text-align: center"
}

properties = {"border": "1px solid black", "width": "90px", "text-align": "center"}

styles = [dict(selector="caption",
                       props=[("text-align", "center"),
                              ("font-size", "150%"),
                              ("color", 'black')])]

p9_log.head(50).style.format(precision=2).highlight_max(axis=0, props='color:white; font-weight:bold; background-color:orange;').set_table_styles(
    styles, [cell_hover, index_names, headers]).set_properties(**properties).set_caption('Log DataFrame')

#p9_log.style.set_sticky(axis='index')
#p9_log.style.set_table_styles([cell_hover, index_names, headers])
#cm = sns.light_palette("orange", as_cmap=True)
#p9_log.style.background_gradient(cmap=cm)

#p9_log.style.highlight_max(axis=0, props='color:white; font-weight:bold; background-color:darkblue;')
# Out:
# <style type="text/css">
# #T_a9810 caption {
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_a9810_row0_col0, #T_a9810_row0_col1, #T_a9810_row0_col2, #T_a9810_row0_col3, #T_a9810_row0_col4, #T_a9810_row0_col6, #T_a9810_row0_col7, #T_a9810_row0_col8, #T_a9810_row0_col9, #T_a9810_row0_col10, #T_a9810_row0_col11, #T_a9810_row0_col12, #T_a9810_row0_col13, #T_a9810_row0_col14, #T_a9810_row0_col15, #T_a9810_row1_col0, #T_a9810_row1_col1, #T_a9810_row1_col2, #T_a9810_row1_col3, #T_a9810_row1_col4, #T_a9810_row1_col6, #T_a9810_row1_col7, #T_a9810_row1_col8, #T_a9810_row1_col9, #T_a9810_row1_col10, #T_a9810_row1_col11, #T_a9810_row1_col12, #T_a9810_row1_col13, #T_a9810_row1_col14, #T_a9810_row1_col15, #T_a9810_row2_col0, #T_a9810_row2_col1, #T_a9810_row2_col2, #T_a9810_row2_col3, #T_a9810_row2_col4, #T_a9810_row2_col6, #T_a9810_row2_col7, #T_a9810_row2_col8, #T_a9810_row2_col9, #T_a9810_row2_col10, #T_a9810_row2_col11, #T_a9810_row2_col12, #T_a9810_row2_col13, #T_a9810_row2_col14, #T_a9810_row2_col15, #T_a9810_row3_col0, #T_a9810_row3_col1, #T_a9810_row3_col2, #T_a9810_row3_col3, #T_a9810_row3_col4, #T_a9810_row3_col6, #T_a9810_row3_col7, #T_a9810_row3_col8, #T_a9810_row3_col9, #T_a9810_row3_col10, #T_a9810_row3_col11, #T_a9810_row3_col12, #T_a9810_row3_col13, #T_a9810_row3_col14, #T_a9810_row3_col15, #T_a9810_row4_col0, #T_a9810_row4_col1, #T_a9810_row4_col2, #T_a9810_row4_col3, #T_a9810_row4_col4, #T_a9810_row4_col6, #T_a9810_row4_col7, #T_a9810_row4_col8, #T_a9810_row4_col9, #T_a9810_row4_col10, #T_a9810_row4_col12, #T_a9810_row4_col13, #T_a9810_row4_col14, #T_a9810_row4_col15, #T_a9810_row5_col0, #T_a9810_row5_col1, #T_a9810_row5_col2, #T_a9810_row5_col3, #T_a9810_row5_col4, #T_a9810_row5_col6, #T_a9810_row5_col7, #T_a9810_row5_col8, #T_a9810_row5_col9, #T_a9810_row5_col10, #T_a9810_row5_col11, #T_a9810_row5_col12, #T_a9810_row5_col13, #T_a9810_row5_col14, #T_a9810_row5_col15, #T_a9810_row6_col0, #T_a9810_row6_col1, #T_a9810_row6_col2, #T_a9810_row6_col3, #T_a9810_row6_col4, #T_a9810_row6_col6, #T_a9810_row6_col7, #T_a9810_row6_col8, #T_a9810_row6_col9, #T_a9810_row6_col10, #T_a9810_row6_col11, #T_a9810_row6_col12, #T_a9810_row6_col13, #T_a9810_row6_col14, #T_a9810_row6_col15, #T_a9810_row7_col0, #T_a9810_row7_col1, #T_a9810_row7_col2, #T_a9810_row7_col3, #T_a9810_row7_col4, #T_a9810_row7_col6, #T_a9810_row7_col7, #T_a9810_row7_col8, #T_a9810_row7_col9, #T_a9810_row7_col10, #T_a9810_row7_col11, #T_a9810_row7_col12, #T_a9810_row7_col13, #T_a9810_row7_col14, #T_a9810_row7_col15, #T_a9810_row8_col0, #T_a9810_row8_col1, #T_a9810_row8_col2, #T_a9810_row8_col3, #T_a9810_row8_col4, #T_a9810_row8_col6, #T_a9810_row8_col7, #T_a9810_row8_col8, #T_a9810_row8_col9, #T_a9810_row8_col10, #T_a9810_row8_col11, #T_a9810_row8_col12, #T_a9810_row8_col13, #T_a9810_row8_col14, #T_a9810_row8_col15, #T_a9810_row9_col0, #T_a9810_row9_col1, #T_a9810_row9_col2, #T_a9810_row9_col3, #T_a9810_row9_col4, #T_a9810_row9_col6, #T_a9810_row9_col7, #T_a9810_row9_col8, #T_a9810_row9_col9, #T_a9810_row9_col10, #T_a9810_row9_col11, #T_a9810_row9_col12, #T_a9810_row9_col13, #T_a9810_row9_col14, #T_a9810_row9_col15, #T_a9810_row10_col1, #T_a9810_row10_col2, #T_a9810_row10_col3, #T_a9810_row10_col4, #T_a9810_row10_col6, #T_a9810_row10_col7, #T_a9810_row10_col9, #T_a9810_row10_col10, #T_a9810_row10_col11, #T_a9810_row10_col12, #T_a9810_row10_col13, #T_a9810_row10_col14, #T_a9810_row10_col15, #T_a9810_row11_col0, #T_a9810_row11_col1, #T_a9810_row11_col2, #T_a9810_row11_col3, #T_a9810_row11_col4, #T_a9810_row11_col6, #T_a9810_row11_col7, #T_a9810_row11_col8, #T_a9810_row11_col9, #T_a9810_row11_col10, #T_a9810_row11_col11, #T_a9810_row11_col12, #T_a9810_row11_col13, #T_a9810_row11_col14, #T_a9810_row11_col15, #T_a9810_row12_col0, #T_a9810_row12_col1, #T_a9810_row12_col2, #T_a9810_row12_col3, #T_a9810_row12_col4, #T_a9810_row12_col6, #T_a9810_row12_col7, #T_a9810_row12_col8, #T_a9810_row12_col9, #T_a9810_row12_col10, #T_a9810_row12_col11, #T_a9810_row12_col12, #T_a9810_row12_col13, #T_a9810_row12_col14, #T_a9810_row12_col15, #T_a9810_row13_col0, #T_a9810_row13_col1 ...

# %% [markdown]
# # Exportations des fichiers

# %%
p9.to_excel('../src/p9_2010_cleaned.xlsx', index=False)
p9_log.to_excel('../src/p9_log_2010_cleaned.xlsx', index=True)
print("Exportation terminée")
# Out:
# Exportation terminée
