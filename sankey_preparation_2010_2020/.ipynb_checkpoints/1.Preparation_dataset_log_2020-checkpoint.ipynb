# %% [markdown]
# # Chargement des librairies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mylib.fonction_exploration import exploration1, exploration2, exploration3, exploration4
from mylib.fonction_pk import test_pk
from mylib.fonction_merge import df_merge
from mylib.fonction_acp import display_circles, display_factorial_planes, display_scree_plot
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats
import seaborn as sns
from pandas_profiling import ProfileReport
import plotly.express as px
from IPython.display import display_html 

from sklearn.cluster import KMeans
from sklearn import decomposition
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn import preprocessing
#from scipy.cluster.hierarchy import dendrogram
from sklearn import metrics
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import AgglomerativeClustering
# to visualize the elbow curve and silhouette scores
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

print("Version numpy : " + np.__version__)
print("Version pandas : " + pd.__version__)

bold = "\033[1m"
red = "\033[31m"
end = "\033[0;0m"

chemin = '../src/df_2020_cleaned.csv'
# Out:
# Version numpy : 1.23.5
# Version pandas : 1.4.4

# %% [markdown]
# # Chargement du fichier nettoyé

# %%
p9 = pd.read_csv(chemin)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # Exploration

# %%
exploration1(p9)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ffda" style='display:grid'>
#   <caption>__________ Head __________</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ffda_level0_col0" class="col_heading level0 col0" >iso</th>
#       <th id="T_1ffda_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_1ffda_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_1ffda_level0_col3" class="col_heading level0 col3" >Under-nourishment (%)</th>
#       <th id="T_1ffda_level0_col4" class="col_heading level0 col4" >HDI</th>
#       <th id="T_1ffda_level0_col5" class="col_heading level0 col5" >Peace_index</th>
#       <th id="T_1ffda_level0_col6" class="col_heading level0 col6" >Vegetables disponibility (kg/cap/year)</th>
#       <th id="T_1ffda_level0_col7" class="col_heading level0 col7" >Enough veg intake (> 91.25 kg/cap/year)</th>
#       <th id="T_1ffda_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_1ffda_level0_col9" class="col_heading level0 col9" >Exportations</th>
#       <th id="T_1ffda_level0_col10" class="col_heading level0 col10" >Importations</th>
#       <th id="T_1ffda_level0_col11" class="col_heading level0 col11" >Customs duration (h)</th>
#       <th id="T_1ffda_level0_col12" class="col_heading level0 col12" >Customs tax (%)</th>
#       <th id="T_1ffda_level0_col13" class="col_heading level0 col13" >Distance (km)</th>
#       <th id="T_1ffda_level0_col14" class="col_heading level0 col14" >Gdp/cap</th>
#       <th id="T_1ffda_level0_col15" class="col_heading level0 col15" >Population evolution (4y, %)</th>
#       <th id="T_1ffda_level0_col16" class="col_heading level0 col16" >Trade balance (exp-imp)</th>
#       <th id="T_1ffda_level0_col17" class="col_heading level0 col17" >Self-sufficiency (prod-dispo)</th>
#       <th id="T_1ffda_level0_col18" class="col_heading level0 col18" >Market growth (2y, %)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ffda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ffda_row0_col0" class="data row0 col0" >AFG</td>
#       <td id="T_1ffda_row0_col1" class="data row0 col1" >Afghanistan</td>
#       <td id="T_1ffda_row0_col2" class="data row0 col2" >38972230</td>
#       <td id="T_1ffda_row0_col3" class="data row0 col3" >29.800000</td>
#       <td id="T_1ffda_row0_col4" class="data row0 col4" >0.483000</td>
#       <td id="T_1ffda_row0_col5" class="data row0 col5" >3.644000</td>
#       <td id="T_1ffda_row0_col6" class="data row0 col6" >107.260000</td>
#       <td id="T_1ffda_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_1ffda_row0_col8" class="data row0 col8" >4777000000</td>
#       <td id="T_1ffda_row0_col9" class="data row0 col9" >421000000</td>
#       <td id="T_1ffda_row0_col10" class="data row0 col10" >537000000</td>
#       <td id="T_1ffda_row0_col11" class="data row0 col11" >48.000000</td>
#       <td id="T_1ffda_row0_col12" class="data row0 col12" >8.380000</td>
#       <td id="T_1ffda_row0_col13" class="data row0 col13" >5500.665000</td>
#       <td id="T_1ffda_row0_col14" class="data row0 col14" >2076.138380</td>
#       <td id="T_1ffda_row0_col15" class="data row0 col15" >12.518758</td>
#       <td id="T_1ffda_row0_col16" class="data row0 col16" >-116000000</td>
#       <td id="T_1ffda_row0_col17" class="data row0 col17" >15.314459</td>
#       <td id="T_1ffda_row0_col18" class="data row0 col18" >-42.993631</td>
#     </tr>
#     <tr>
#       <th id="T_1ffda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ffda_row1_col0" class="data row1 col0" >ZAF</td>
#       <td id="T_1ffda_row1_col1" class="data row1 col1" >South Africa</td>
#       <td id="T_1ffda_row1_col2" class="data row1 col2" >58801927</td>
#       <td id="T_1ffda_row1_col3" class="data row1 col3" >6.900000</td>
#       <td id="T_1ffda_row1_col4" class="data row1 col4" >0.727000</td>
#       <td id="T_1ffda_row1_col5" class="data row1 col5" >2.317000</td>
#       <td id="T_1ffda_row1_col6" class="data row1 col6" >156.440000</td>
#       <td id="T_1ffda_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_1ffda_row1_col8" class="data row1 col8" >20787000000</td>
#       <td id="T_1ffda_row1_col9" class="data row1 col9" >3831000000</td>
#       <td id="T_1ffda_row1_col10" class="data row1 col10" >461000000</td>
#       <td id="T_1ffda_row1_col11" class="data row1 col11" >92.000000</td>
#       <td id="T_1ffda_row1_col12" class="data row1 col12" >7.110000</td>
#       <td id="T_1ffda_row1_col13" class="data row1 col13" >8769.679000</td>
#       <td id="T_1ffda_row1_col14" class="data row1 col14" >13517.780586</td>
#       <td id="T_1ffda_row1_col15" class="data row1 col15" >4.217577</td>
#       <td id="T_1ffda_row1_col16" class="data row1 col16" >3370000000</td>
#       <td id="T_1ffda_row1_col17" class="data row1 col17" >197.068823</td>
#       <td id="T_1ffda_row1_col18" class="data row1 col18" >35.190616</td>
#     </tr>
#     <tr>
#       <th id="T_1ffda_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ffda_row2_col0" class="data row2 col0" >ALB</td>
#       <td id="T_1ffda_row2_col1" class="data row2 col1" >Albania</td>
#       <td id="T_1ffda_row2_col2" class="data row2 col2" >2837849</td>
#       <td id="T_1ffda_row2_col3" class="data row2 col3" >3.900000</td>
#       <td id="T_1ffda_row2_col4" class="data row2 col4" >0.794000</td>
#       <td id="T_1ffda_row2_col5" class="data row2 col5" >1.872000</td>
#       <td id="T_1ffda_row2_col6" class="data row2 col6" >390.020000</td>
#       <td id="T_1ffda_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_1ffda_row2_col8" class="data row2 col8" >1967000000</td>
#       <td id="T_1ffda_row2_col9" class="data row2 col9" >136000000</td>
#       <td id="T_1ffda_row2_col10" class="data row2 col10" >119000000</td>
#       <td id="T_1ffda_row2_col11" class="data row2 col11" >9.000000</td>
#       <td id="T_1ffda_row2_col12" class="data row2 col12" >1.450000</td>
#       <td id="T_1ffda_row2_col13" class="data row2 col13" >1499.451000</td>
#       <td id="T_1ffda_row2_col14" class="data row2 col14" >13759.542434</td>
#       <td id="T_1ffda_row2_col15" class="data row2 col15" >-1.329995</td>
#       <td id="T_1ffda_row2_col16" class="data row2 col16" >17000000</td>
#       <td id="T_1ffda_row2_col17" class="data row2 col17" >303.110607</td>
#       <td id="T_1ffda_row2_col18" class="data row2 col18" >3.478261</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_14628" style='display:grid'>
#   <caption>__________ Tail __________</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14628_level0_col0" class="col_heading level0 col0" >iso</th>
#       <th id="T_14628_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_14628_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_14628_level0_col3" class="col_heading level0 col3" >Under-nourishment (%)</th>
#       <th id="T_14628_level0_col4" class="col_heading level0 col4" >HDI</th>
#       <th id="T_14628_level0_col5" class="col_heading level0 col5" >Peace_index</th>
#       <th id="T_14628_level0_col6" class="col_heading level0 col6" >Vegetables disponibility (kg/cap/year)</th>
#       <th id="T_14628_level0_col7" class="col_heading level0 col7" >Enough veg intake (> 91.25 kg/cap/year)</th>
#       <th id="T_14628_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_14628_level0_col9" class="col_heading level0 col9" >Exportations</th>
#       <th id="T_14628_level0_col10" class="col_heading level0 col10" >Importations</th>
#       <th id="T_14628_level0_col11" class="col_heading level0 col11" >Customs duration (h)</th>
#       <th id="T_14628_level0_col12" class="col_heading level0 col12" >Customs tax (%)</th>
#       <th id="T_14628_level0_col13" class="col_heading level0 col13" >Distance (km)</th>
#       <th id="T_14628_level0_col14" class="col_heading level0 col14" >Gdp/cap</th>
#       <th id="T_14628_level0_col15" class="col_heading level0 col15" >Population

# %%
exploration2(p9)
# Out:
#                                         Nombre de valeurs totales  \
# iso                                                           143
# Country                                                       143
# Population                                                    143
# Under-nourishment (%)                                         143
# HDI                                                           143
# Peace_index                                                   143
# Vegetables disponibility (kg/cap/year)                        143
# Enough veg intake (> 91.25 kg/cap/year)                       143
# Production                                                    143
# Exportations                                                  143
# Importations                                                  143
# Customs duration (h)                                          143
# Customs tax (%)                                               143
# Distance (km)                                                 143
# Gdp/cap                                                       143
# Population evolution (4y, %)                                  143
# Trade balance (exp-imp)                                       143
# Self-sufficiency (prod-dispo)                                 143
# Market growth (2y, %)                                         143
#
#                                         Type des données Nombre de NaN  \
# iso                                               object             0
# Country                                           object             0
# Population                                         int64             0
# Under-nourishment (%)                            float64             0
# HDI                                              float64             0
# Peace_index                                      float64             0
# Vegetables disponibility (kg/cap/year)           float64             0
# Enough veg intake (> 91.25 kg/cap/year)            int64             0
# Production                                         int64             0
# Exportations                                       int64             0
# Importations                                       int64             0
# Customs duration (h)                             float64             0
# Customs tax (%)                                  float64             0
# Distance (km)                                    float64             0
# Gdp/cap                                          float64             0
# Population evolution (4y, %)                     float64             0
# Trade balance (exp-imp)                            int64             0
# Self-sufficiency (prod-dispo)                    float64             0
# Market growth (2y, %)                            float64             0
#
#                                         NaN en % Nombre de valeurs uniques  \
# iso                                         0.00                       143
# Country                                     0.00                       143
# Population                                  0.00                       143
# Under-nourishment (%)                       0.00                        77
# HDI                                         0.00                       124
# Peace_index                                 0.00                       134
# Vegetables disponibility (kg/cap/year)      0.00                       143
# Enough veg intake (> 91.25 kg/cap/year)     0.00                         2
# Production                                  0.00                       142
# Exportations                                0.00                       116
# Importations                                0.00                       139
# Customs duration (h)                        0.00                        96
# Customs tax (%)                             0.00                       118
# Distance (km)                               0.00                       143
# Gdp/cap                                     0.00                       143
# Population evolution (4y, %)                0.00                       143
# Trade balance (exp-imp)                     0.00                       138
# Self-sufficiency (prod-dispo)               0.00                       143
# Market growth (2y, %)                       0.00                       141
#
#                                         Valeurs uniques en%
# iso                                                  100.00
# Country                                              100.00
# Population                                           100.00
# Under-nourishment (%)                                 53.85
# HDI                                                   86.71
# Peace_index                                           93.71
# Vegetables disponibility (kg/cap/year)               100.00
# Enough veg intake (> 91.25 kg/cap/year)                1.40
# Production                                            99.30
# Exportations                                          81.12
# Importations                                          97.20
# Customs duration (h)                                  67.13
# Customs tax (%)                                       82.52
# Distance (km)                                        100.00
# Gdp/cap                                              100.00
# Population evolution (4y, %)                         100.00
# Trade balance (exp-imp)                               96.50
# Self-sufficiency (prod-dispo)                        100.00
# Market growth (2y, %)                                 98.60

# %%
exploration3(p9)
# Out:
# ---------------------------------------
# Nombre de lignes et de colonnes (shape)
# ---------------------------------------
#
# (143, 19)
#
# --------------------------------------
# Affichage des NaN (isna().any(axis=1))
# --------------------------------------
#
# Empty DataFrame
# Columns: [iso, Country, Population, Under-nourishment (%), HDI, Peace_index, Vegetables disponibility (kg/cap/year), Enough veg intake (> 91.25 kg/cap/year), Production, Exportations, Importations, Customs duration (h), Customs tax (%), Distance (km), Gdp/cap, Population evolution (4y, %), Trade balance (exp-imp), Self-sufficiency (prod-dispo), Market growth (2y, %)]
# Index: []
#
# ---------------------------------------
# Nombre de doublons (duplicated().sum())
# ---------------------------------------
#
# 0
#
# -----------------------------------------------------
# Affichage des doublons (df[df.duplicated()].head(10))
# -----------------------------------------------------
#
# Empty DataFrame
# Columns: [iso, Country, Population, Under-nourishment (%), HDI, Peace_index, Vegetables disponibility (kg/cap/year), Enough veg intake (> 91.25 kg/cap/year), Production, Exportations, Importations, Customs duration (h), Customs tax (%), Distance (km), Gdp/cap, Population evolution (4y, %), Trade balance (exp-imp), Self-sufficiency (prod-dispo), Market growth (2y, %)]
# Index: []

# %%
exploration4(p9)
# Out:
#                                          count unique          top freq  \
# iso                                        143    143          AFG    1
# Country                                    143    143  Afghanistan    1
# Population                              143.00    NaN          NaN  NaN
# Under-nourishment (%)                   143.00    NaN          NaN  NaN
# HDI                                     143.00    NaN          NaN  NaN
# Peace_index                             143.00    NaN          NaN  NaN
# Vegetables disponibility (kg/cap/year)  143.00    NaN          NaN  NaN
# Enough veg intake (> 91.25 kg/cap/year) 143.00    NaN          NaN  NaN
# Production                              143.00    NaN          NaN  NaN
# Exportations                            143.00    NaN          NaN  NaN
# Importations                            143.00    NaN          NaN  NaN
# Customs duration (h)                    143.00    NaN          NaN  NaN
# Customs tax (%)                         143.00    NaN          NaN  NaN
# Distance (km)                           143.00    NaN          NaN  NaN
# Gdp/cap                                 143.00    NaN          NaN  NaN
# Population evolution (4y, %)            143.00    NaN          NaN  NaN
# Trade balance (exp-imp)                 143.00    NaN          NaN  NaN
# Self-sufficiency (prod-dispo)           143.00    NaN          NaN  NaN
# Market growth (2y, %)                   143.00    NaN          NaN  NaN
#
#                                                   mean            std  \
# iso                                                NaN            NaN
# Country                                            NaN            NaN
# Population                                 52597358.57   169949879.41
# Under-nourishment (%)                             9.95          10.49
# HDI                                               0.73           0.15
# Peace_index                                       2.05           0.46
# Vegetables disponibility (kg/cap/year)          198.53          95.99
# Enough veg intake (> 91.25 kg/cap/year)           0.94           0.24
# Production                              23284202797.20 99709754068.79
# Exportations                             2625825174.83  7631577991.36
# Importations                             2431482517.48  5290997259.30
# Customs duration (h)                             51.47          54.12
# Customs tax (%)                                   6.50           4.75
# Distance (km)                                  5487.04        3601.23
# Gdp/cap                                       20322.55       18923.59
# Population evolution (4y, %)                      5.09           4.79
# Trade balance (exp-imp)                   194342657.34  7232250516.73
# Self-sufficiency (prod-dispo)                   158.49         264.74
# Market growth (2y, %)                            21.21          77.19
#
#                                                     min           25%  \
# iso                                                 NaN           NaN
# Country                                             NaN           NaN
# Population                                    366463.00    5106652.50
# Under-nourishment (%)                              2.50          2.50
# HDI                                                0.40          0.60
# Peace_index                                        1.08          1.74
# Vegetables disponibility (kg/cap/year)            29.67        133.20
# Enough veg intake (> 91.25 kg/cap/year)            0.00          1.00
# Production                                  11000000.00 1155500000.00
# Exportations                                       0.00   19500000.00
# Importations                                 5000000.00  167500000.00
# Customs duration (h)                               0.00          8.75
# Customs tax (%)                                    0.27          1.96
# Distance (km)                                    408.96       2063.64
# Gdp/cap                                         1101.25       5174.78
# Population evolution (4y, %)                      -9.52          1.74
# Trade balance (exp-imp)                 -29902000000.00 -748000000.00
# Self-sufficiency (prod-dispo)                   -132.48          8.32
# Market growth (2y, %)                            -61.76         -6.55
#
#                                                   50%            75%  \
# iso                                               NaN            NaN
# Country                                           NaN            NaN
# Population                                11538604.00    37968137.00
# Under-nourishment (%)                            5.10          15.35
# HDI                                              0.74           0.85
# Peace_index                                      2.03           2.26
# Vegetables disponibility (kg/cap/year)         173.00         246.45
# Enough veg intake (> 91.25 kg/cap/year)          1.00           1.00
# Production                              4054000000.00 13212500000.00
# Exportations                             147000000.00  1040000000.00
# Importations                             591000000.00  2200000000.00
# Customs duration (h)                            37.00          72.00
# Customs tax (%)                                  5.08          10.36
# Distance (km)                                 5147.52        8506.79
# Gdp/cap                                      14089.24       31390.68
# Population evolution (4y, %)                     5.02           8.33
# Trade balance (exp-imp)                 -159000000.00    46500000.00
# Self-sufficiency (prod-dispo)                   56.10         202.18
# Market growth (2y, %)                            6.81          25.09
#
#                                                      max
# iso                                                  NaN
# Country                                              NaN
# Population                                 1411100000.00
# Under-nourishment (%)                              48.50
# HDI                                                 0.96
# Peace_index                                         3.64
# Vegetables disponibility (kg/cap/year)            466.41
# Enough veg intake (> 91.25 kg/cap/year)             1.00
# Production                              1083161000000.00
# Exportations                              62049000000.00
# Importations                              46916000000.00
# Customs duration (h)                              296.00
# Customs tax (%)                                    18.92
# Distance (km)                                   18894.29
# Gdp/cap                                         93355.56
# Population evolution (4y, %)                       16.31
# Trade balance (exp-imp)                   44661000000.00
# Self-sufficiency (prod-dispo)                    1334.49
# Market growth (2y, %)                             825.21

# %%
p9.sample()
# Out:
#      iso  Country  Population  Under-nourishment (%)  HDI  Peace_index  \
# 134  VNM  Vietnam    96648685                   5.70 0.71         1.92
#
#      Vegetables disponibility (kg/cap/year)  \
# 134                                  212.02
#
#      Enough veg intake (> 91.25 kg/cap/year)   Production  Exportations  \
# 134                                        1  35473000000   11184000000
#
#      Importations  Customs duration (h)  Customs tax (%)  Distance (km)  \
# 134   13044000000                 55.00             5.56        9888.43
#
#      Gdp/cap  Population evolution (4y, %)  Trade balance (exp-imp)  \
# 134 11022.96                          3.78              -1860000000
#
#      Self-sufficiency (prod-dispo)  Market growth (2y, %)
# 134                         155.01                  24.38

# %% [markdown]
# # Vérification des outliers en prévision de l'ACP

# %%
# on détermine les colonnes numériques
num = []
for i in p9.columns:
    if p9[i].dtypes == int or p9[i].dtypes == float:
        num.append(i)

# %% [markdown]
# ## Z-score

# %%
# on calcule le z-score sur toutes les variables numériques
for i in num:
    p9.sort_values(by=i, inplace=True)
    outlier_z = p9[stats.zscore(p9[i]) > 1.96]
    nb_outlier_z = len(outlier_z)
    print(bold + f"\n{i} : {nb_outlier_z} outliers \n\n" + end + f"{outlier_z[['Country', i]]} \n" + "-" * 50)
# Out:
# Population : 2 outliers
#
#    Country  Population
# 53   India  1396387127
# 26   China  1411100000
# --------------------------------------------------
#
# Under-nourishment (%) : 10 outliers
#
#               Country  Under-nourishment (%)
# 29        Congo, Rep.                  31.60
# 123              Chad                  32.70
# 84         Mozambique                  32.70
# 67            Lesotho                  34.70
# 107            Rwanda                  35.80
# 71            Liberia                  38.30
# 111  Congo, Dem. Rep.                  39.80
# 135       Yemen, Rep.                  41.40
# 50              Haiti                  47.20
# 74         Madagascar                  48.50
# --------------------------------------------------
#
# HDI : 0 outliers
#
# Empty DataFrame
# Columns: [Country, HDI]
# Index: []
# --------------------------------------------------
#
# Peace_index : 7 outliers
#
#                 Country  Peace_index
# 131             Turkiye         2.96
# 96             Pakistan         2.97
# 41   Russian Federation         3.05
# 111    Congo, Dem. Rep.         3.24
# 70                Libya         3.26
# 135         Yemen, Rep.         3.41
# 0           Afghanistan         3.64
# --------------------------------------------------
#
# Vegetables disponibility (kg/cap/year) : 7 outliers
#
#               Country  Vegetables disponibility (kg/cap/year)
# 2             Albania                                  390.02
# 31            Croatia                                  397.67
# 32      Cote d'Ivoire                                  401.04
# 76             Malawi                                  421.92
# 26              China                                  451.12
# 111  Congo, Dem. Rep.                                  460.87
# 44              Ghana                                  466.41
# --------------------------------------------------
#
# Enough veg intake (> 91.25 kg/cap/year) : 0 outliers
#
# Empty DataFrame
# Columns: [Country, Enough veg intake (> 91.25 kg/cap/year)]
# Index: []
# --------------------------------------------------
#
# Production : 3 outliers
#
#            Country     Production
# 53           India   249308000000
# 141  United States   419418000000
# 26           China  1083161000000
# --------------------------------------------------
#
# Exportations : 5 outliers
#
#            Country  Exportations
# 125       Thailand   19959000000
# 132        Ukraine   28953000000
# 17          Brazil   35567000000
# 7        Argentina   38354000000
# 141  United States   62049000000
# --------------------------------------------------
#
# Importations : 6 outliers
#
#            Country  Importations
# 134        Vietnam   13044000000
# 108    Korea, Rep.   13559000000
# 81          Mexico   17227000000
# 141  United States   17388000000
# 61           Japan   18970000000
# 26           China   46916000000
# --------------------------------------------------
#
# Customs duration (h) : 7 outliers
#
#               Country  Customs duration (h)
# 5              Angola                164.00
# 12         Bangladesh                168.00
# 71            Liberia                193.00
# 23           Cameroon                202.00
# 32      Cote d'Ivoire                238.71
# 29        Congo, Rep.                276.00
# 111  Congo, Dem. Rep.                296.00
# --------------------------------------------------
#
# Customs tax (%) : 5 outliers
#
#       Country  Customs tax (%)
# 142  Ethiopia            17.83
# 123      Chad            18.16
# 23   Cameroon            18.56
# 42      Gabon            18.65
# 34   Djibouti            18.92
# --------------------------------------------------
#
# Distance (km) : 4 outliers
#
#               Country  Distance (km)
# 126       Timor-Leste       13175.21
# 98   Papua New Guinea       14488.95
# 9           Australia       16513.02
# 91        New Zealand       18894.29
# --------------------------------------------------
#
# Gdp/cap : 7 outliers
#
#                   Country  Gdp/cap
# 100           Netherlands 59266.91
# 33                Denmark 60229.91
# 90                 Norway 62644.85
# 141         United States 63027.68
# 139  United Arab Emirates 71374.18
# 119           Switzerland 71731.96
# 56                Ireland 93355.56
# --------------------------------------------------
#
# Population evolution (4y, %) : 3 outliers
#
#    Country  Population evolution (4y, %)
# 94  Uganda                         14.60
# 5   Angola                         14.66
# 88   Niger                         16.31
# --------------------------------------------------
#
# Trade balance (exp-imp) : 4 outliers
#
#            Country  Trade balance (exp-imp)
# 132        Ukraine              28327000000
# 17          Brazil              32456000000
# 7        Argentina              38191000000
# 141  United States              44661000000
# --------------------------------------------------
#
# Self-sufficiency (prod-dispo) : 6 outliers
#
#            Country  Self-sufficiency (prod-dispo)
# 52         Hungary                         903.06
# 141  United States                        1076.46
# 132        Ukraine                        1081.25
# 99        Paraguay                        1132.52
# 114         Serbia                        1211.53
# 7        Argentina                        1334.49
# --------------------------------------------------
#
# Market growth (2y, %) : 1 outliers
#
#       Country  Market growth (2y, %)
# 137  Zimbabwe                 825.21
# --------------------------------------------------

# %% [markdown]
# ## Log

# %%
p9_log = p9.copy()
p9_log = p9_log.set_index(['Country'])
p9_log = p9_log[num]
p9_log.sample()
# Out:
#          Population  Under-nourishment (%)  HDI  Peace_index  \
# Country
# Oman        4543399                   9.80 0.83         1.94
#
#          Vegetables disponibility (kg/cap/year)  \
# Country
# Oman                                     229.23
#
#          Enough veg intake (> 91.25 kg/cap/year)  Production  Exportations  \
# Country
# Oman                                           1   965000000      96000000
#
#          Importations  Customs duration (h)  Customs tax (%)  Distance (km)  \
# Country
# Oman        772000000                 27.50             3.24        5495.84
#
#          Gdp/cap  Population evolution (4y, %)  Trade balance (exp-imp)  \
# Country
# Oman    34910.85                          3.30               -676000000
#
#          Self-sufficiency (prod-dispo)  Market growth (2y, %)
# Country
# Oman                            -16.83                  10.76

# %% [markdown]
# ### Graphiques de distribution

# %%
f, a = plt.subplots(6, 3, figsize=(20,40))
a = a.flatten()
for i, col in enumerate(p9_log.columns):
    sns.distplot(p9_log[col], ax=a[i], kde= True).set_title('Skew: {:.2f}'.format(p9_log[col].skew()))
plt.show()

# %% [raw]
# #Plot a Histogram of the data
# #fig, axes = plt.subplots(5, 3, figsize=(25, 20))
# for i in p9_log.columns:
#     ax = sns.distplot(p9_log[i], kde=True)
# #ax.set(xlabel= ‘Garage Area (ft²)’, ylabel=’Counts’, title=’Frequency of Garage Sizes (ft²)’)
#     plt.show()

# %% [markdown]
# ### Calcul de Skew et Kurtosis

# %%
#Calculating Skew and Kurtosis 
for i in p9_log.columns:
    kurtosis = round((stats.kurtosis(p9_log[i])), ndigits=2)
    skew = round((stats.skew(p9_log[i])), ndigits=2)
    #print("\nkurtosis :", i, kurtosis) 
    #print("skew", i, skew, "\n")
    print("\n" + "-" * 50 + bold + f"\n{i} : kurtosis {kurtosis}" + end)
    print(bold + f"{i} : skew {skew} \n" + end)
#Interpreting Kurtosis
    if  -0.5 < kurtosis < 0.5:
        print (f'A kurtosis of {kurtosis} means the distribution is approximately normal sometimes called mesokurtic distributions')
    elif kurtosis <= -0.5: 
        print (f'A kurtosis of {kurtosis} means the distribution is light-tailed (negative) sometimes called a platykurtic distributions')
    elif kurtosis >= 0.5:
        print (f'A kurtosis of {kurtosis} means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution')
#Interpreting Skewness
    if -0.5 < skew < 0.5:
        print (f'A skew of {skew} means the distribution is approx. symmetric')
    elif  -1 < skew < -0.5 or 0.5 < skew < 1.0:
        print (f'A skew of {skew} means the distribution is moderately skewed')
    else:
        print (f'A skew of {skew} means the distribution is highly skewed')
# Out:
# --------------------------------------------------
# Population : kurtosis 53.77
# Population : skew 7.16
#
# A kurtosis of 53.77 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 7.16 means the distribution is highly skewed
#
# --------------------------------------------------
# Under-nourishment (%) : kurtosis 2.25
# Under-nourishment (%) : skew 1.68
#
# A kurtosis of 2.25 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.68 means the distribution is highly skewed
#
# --------------------------------------------------
# HDI : kurtosis -1.01
# HDI : skew -0.3
#
# A kurtosis of -1.01 means the distribution is light-tailed (negative) sometimes called a platykurtic distributions
# A skew of -0.3 means the distribution is approx. symmetric
#
# --------------------------------------------------
# Peace_index : kurtosis 0.83
# Peace_index : skew 0.69
#
# A kurtosis of 0.83 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 0.69 means the distribution is moderately skewed
#
# --------------------------------------------------
# Vegetables disponibility (kg/cap/year) : kurtosis 0.02
# Vegetables disponibility (kg/cap/year) : skew 0.85
#
# A kurtosis of 0.02 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.85 means the distribution is moderately skewed
#
# --------------------------------------------------
# Enough veg intake (> 91.25 kg/cap/year) : kurtosis 10.96
# Enough veg intake (> 91.25 kg/cap/year) : skew -3.6
#
# A kurtosis of 10.96 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of -3.6 means the distribution is highly skewed
#
# --------------------------------------------------
# Production : kurtosis 89.52
# Production : skew 9.03
#
# A kurtosis of 89.52 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 9.03 means the distribution is highly skewed
#
# --------------------------------------------------
# Exportations : kurtosis 30.3
# Exportations : skew 5.09
#
# A kurtosis of 30.3 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 5.09 means the distribution is highly skewed
#
# --------------------------------------------------
# Importations : kurtosis 34.61
# Importations : skew 5.03
#
# A kurtosis of 34.61 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 5.03 means the distribution is highly skewed
#
# --------------------------------------------------
# Customs duration (h) : kurtosis 4.59
# Customs duration (h) : skew 1.85
#
# A kurtosis of 4.59 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.85 means the distribution is highly skewed
#
# --------------------------------------------------
# Customs tax (%) : kurtosis -0.53
# Customs tax (%) : skew 0.72
#
# A kurtosis of -0.53 means the distribution is light-tailed (negative) sometimes called a platykurtic distributions
# A skew of 0.72 means the distribution is moderately skewed
#
# --------------------------------------------------
# Distance (km) : kurtosis 0.44
# Distance (km) : skew 0.69
#
# A kurtosis of 0.44 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.69 means the distribution is moderately skewed
#
# --------------------------------------------------
# Gdp/cap : kurtosis 0.94
# Gdp/cap : skew 1.2
#
# A kurtosis of 0.94 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.2 means the distribution is highly skewed
#
# --------------------------------------------------
# Population evolution (4y, %) : kurtosis -0.26
# Population evolution (4y, %) : skew -0.08
#
# A kurtosis of -0.26 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of -0.08 means the distribution is approx. symmetric
#
# --------------------------------------------------
# Trade balance (exp-imp) : kurtosis 19.6
# Trade balance (exp-imp) : skew 3.0
#
# A kurtosis of 19.6 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 3.0 means the distribution is highly skewed
#
# --------------------------------------------------
# Self-sufficiency (prod-dispo) : kurtosis 5.91
# Self-sufficiency (prod-dispo) : skew 2.34
#
# A kurtosis of 5.91 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 2.34 means the distribution is highly skewed
#
# --------------------------------------------------
# Market growth (2y, %) : kurtosis 80.76
# Market growth (2y, %) : skew 8.11
#
# A kurtosis of 80.76 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 8.11 means the distribution is highly skewed

# %% [markdown]
# ### Test de normalité

# %%
# calculate
for i in p9_log.columns:
    stat, p = stats.normaltest(p9_log[i])
    print (bold + f'{i}' + end + f': \nStatistic={stat}, p={p}')
   # print ('--'*25) 

# interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
        print ('--'*25) 
    else:
        print('Sample does not look Gaussian (reject H0)')
        print ('--'*25)
# Out:
# Population:
# Statistic=231.93907753963126, p=4.3158788320933137e-51
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Under-nourishment (%):
# Statistic=51.116850960351414, p=7.945419791236163e-12
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# HDI:
# Statistic=25.46662007217748, p=2.9511665175722794e-06
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Peace_index:
# Statistic=14.147117231674617, p=0.0008472128333470512
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Vegetables disponibility (kg/cap/year):
# Statistic=14.932567506329475, p=0.0005720502314815573
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Enough veg intake (> 91.25 kg/cap/year):
# Statistic=130.0667306911416, p=5.706479886021093e-29
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Production:
# Statistic=268.95348801349576, p=3.95814895311021e-59
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Exportations:
# Statistic=184.03992818388429, p=1.0870195875693093e-40
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Importations:
# Statistic=185.6532237153877, p=4.851931897710004e-41
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Customs duration (h):
# Statistic=66.88604038815862, p=2.991443960705811e-15
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Customs tax (%):
# Statistic=13.65355768985063, p=0.0010843453426449307
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Distance (km):
# Statistic=11.960894479310873, p=0.002527695553704063
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Gdp/cap:
# Statistic=29.460581944751723, p=4.0060458342655634e-07
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Population evolution (4y, %):
# Statistic=0.38159257898970145, p=0.826300897180623
# Sample looks Gaussian (fail to reject H0)
# --------------------------------------------------
# Trade balance (exp-imp):
# Statistic=128.46859968492282, p=1.2688141972833047e-28
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Self-sufficiency (prod-dispo):
# Statistic=85.41633472130054, p=2.8319043661220784e-19
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Market growth (2y, %):
# Statistic=254.14243160193075, p=6.511366921117192e-56
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------

# %%
#pip install outliers

# %%
#import numpy as np
#from OUTLIERS import smirnov_grubbs as grubbs

#grubbs.max_test(p9.Population, alpha=.01)

# %% [markdown]
# ### Mise en log des colonnes éligibles

# %%
p9.columns
# Out:
# Index(['iso', 'Country', 'Population', 'Under-nourishment (%)', 'HDI',
#        'Peace_index', 'Vegetables disponibility (kg/cap/year)',
#        'Enough veg intake (> 91.25 kg/cap/year)', 'Production', 'Exportations',
#        'Importations', 'Customs duration (h)', 'Customs tax (%)',
#        'Distance (km)', 'Gdp/cap', 'Population evolution (4y, %)',
#        'Trade balance (exp-imp)', 'Self-sufficiency (prod-dispo)',
#        'Market growth (2y, %)'],
#       dtype='object')

# %%
# Data varies in several magnitudes and has both positive, zero and negative numbers  
# log modulus transform 
log_columns = ['Population', 'Under-nourishment (%)', 'Peace_index', 'Vegetables disponibility (kg/cap/year)',
              'Production', 'Exportations', 'Importations', 'Customs duration (h)', 'Customs tax (%)',
               'Distance (km)', 'Gdp/cap', 'Trade balance (exp-imp)', 
               'Self-sufficiency (prod-dispo)', 'Market growth (2y, %)']
for i in log_columns:
    p9_log[i] = np.sign(p9_log[i])*(np.log10(np.abs(p9_log[i])+1))
    
p9_log
# Out:
#                  Population  Under-nourishment (%)  HDI  Peace_index  \
# Country
# Uruguay                6.54                   0.54 0.82         0.43
# Afghanistan            7.59                   1.49 0.48         0.67
# Myanmar                7.73                   0.61 0.60         0.53
# Belarus                6.97                   0.54 0.81         0.49
# Gambia, The            6.41                   1.35 0.50         0.47
# ...                     ...                    ...  ...          ...
# Kyrgyz Republic        6.82                   0.80 0.69         0.49
# Tanzania               7.79                   1.37 0.55         0.45
# Lao PDR                6.86                   0.79 0.61         0.45
# Uganda                 7.65                   1.34 0.52         0.51
# Zimbabwe               7.20                   1.34 0.60         0.54
#
#                  Vegetables disponibility (kg/cap/year)  \
# Country
# Uruguay                                            2.16
# Afghanistan                                        2.03
# Myanmar                                            2.06
# Belarus                                            2.51
# Gambia, The                                        1.49
# ...                                                 ...
# Kyrgyz Republic                                    2.51
# Tanzania                                           2.44
# Lao PDR                                            2.43
# Uganda                                             2.26
# Zimbabwe                                           2.07
#
#                  Enough veg intake (> 91.25 kg/cap/year)  Production  \
# Country
# Uruguay                                                1        9.05
# Afghanistan                                            1        9.68
# Myanmar                                                1       10.07
# Belarus                                                1        9.93
# Gambia, The                                            0        7.68
# ...                                                  ...         ...
# Kyrgyz Republic                                        1        9.55
# Tanzania                                               1       10.39
# Lao PDR                                                1        9.79
# Uganda                                                 1       10.01
# Zimbabwe                                               1        9.25
#
#                  Exportations  Importations  Customs duration (h)  \
# Country
# Uruguay                  6.00          8.40                  1.99
# Afghanistan              8.62          8.73                  1.69
# Myanmar                  9.44          7.54                  2.15
# Belarus                  8.88          8.61                  0.92
# Gambia, The              0.00          7.45                  2.04
# ...                       ...           ...                   ...
# Kyrgyz Republic          8.35          8.16                  0.78
# Tanzania                 8.80          8.12                  1.99
# Lao PDR                  9.59          7.92                  1.00
# Uganda                   8.71          8.38                  1.78
# Zimbabwe                 7.04          9.04                  1.95
#
#                  Customs tax (%)  Distance (km)  Gdp/cap  \
# Country
# Uruguay                     1.04           4.03     4.36
# Afghanistan                 0.97           3.74     3.32
# Myanmar                     0.67           3.94     3.72
# Belarus                     0.79           3.29     4.31
# Gambia, The                 1.17           3.62     3.33
# ...                          ...            ...      ...
# Kyrgyz Republic             0.69           3.74     3.70
# Tanzania                    1.12           3.83     3.43
# Lao PDR                     0.57           3.97     3.91
# Uganda                      1.15           3.77     3.37
# Zimbabwe                    1.02           3.89     3.32
#
#                  Population evolution (4y, %)  Trade balance (exp-imp)  \
# Country
# Uruguay                                  0.45                    -8.40
# Afghanistan                             12.52                    -8.06
# Myanmar                                  2.95                     9.44
# Belarus                                 -0.94                     8.55
# Gambia, The                             11.08                    -7.45
# ...                                       ...                      ...
# Kyrgyz Republic                          8.23                     7.90
# Tanzania                                13.42                     8.69
# Lao PDR                                  6.21                     9.58
# Uganda                                  14.60                     8.44
# Zimbabwe                                 8.42                    -9.04
#
#                  Self-sufficiency (prod-dispo)  Market growth (2y, %)
# Country
# Uruguay                                   2.26                  -1.80
# Afghanistan                               1.21                  -1.64
# Myanmar                                   2.04                  -1.61
# Belarus                                   2.76                  -1.53
# Gambia, The                              -1.08                  -1.51
# ...                                        ...                    ...
# Kyrgyz Republic                           2.35                   2.11
# Tanzania                                  2.09                   2.12
# Lao PDR                                   2.76                   2.18
# Uganda                                    1.71                   2.23
# Zimbabwe                                 -0.48                   2.92
#
# [143 rows x 17 columns]

# %% [markdown]
# ## **Boxplots**

# %%
# création boxplots
fig=plt.figure(figsize=(25,15))
p9_log.boxplot(vert=False)
plt.yticks(size=20)
plt.show()

# %%
#pd.options.display.max_rows = None

# %% [markdown]
# # Vérification des corrélations

# %% [markdown]
# <span style="color:red">**Les distributions des variables n'étant pas toutes normales, nous allons utiliser le test de Spearman pour avoir un aperçu des corrélations**</span>

# %% [markdown]
# ## Corrélation de Spearman

# %%
corr = p9_log.corr(method='spearman')
#corr

# %%
plt.figure(figsize=(20,20))
sns.heatmap(p9_log.corr(method='spearman'), annot=True, annot_kws={"size": 14}, fmt=".2f")
plt.xticks(size=15)
plt.yticks(size=15)
plt.title("\nCorrelations on all numeric features\n", size=30, fontweight='bold' )
plt.show()

# %%
# Beaucoup d'informations, on va visualiser les corrélations les plus élevées
plt.figure(figsize=(20, 20))
sns.heatmap(np.round(corr, 2)[(corr >= 0.4) | (corr <= -0.4)], 
            vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 15}, square=True)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title("\nHighest correlations\n", size=25, fontweight='bold' )
;
# Out:
# ''

# %% [markdown]
# # Visionnage du DataFrame final (log) avant analyse

# %%
cell_hover = {
    "selector": "td:hover",
    "props": [("background-color", "#FFFFE0")]
}
index_names = {
    "selector": ".index_name",
    "props": "background-color: #DC7633; font-style: italic; color: white; font-weight:normal;"
}
headers = {
    "selector": "th:not(.index_name)",
    "props": "background-color: #DC7633; color: white; text-align: center"
}

properties = {"border": "1px solid black", "width": "90px", "text-align": "center"}

styles = [dict(selector="caption",
                       props=[("text-align", "center"),
                              ("font-size", "150%"),
                              ("color", 'black')])]

p9_log.head(50).style.format(precision=2).highlight_max(axis=0, props='color:white; font-weight:bold; background-color:darkblue;').set_table_styles(
    styles, [cell_hover, index_names, headers]).set_properties(**properties).set_caption('Log DataFrame')

#p9_log.style.set_sticky(axis='index')
#p9_log.style.set_table_styles([cell_hover, index_names, headers])
#cm = sns.light_palette("orange", as_cmap=True)
#p9_log.style.background_gradient(cmap=cm)

#p9_log.style.highlight_max(axis=0, props='color:white; font-weight:bold; background-color:darkblue;')
# Out:
# <style type="text/css">
# #T_f56bb caption {
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_f56bb_row0_col0, #T_f56bb_row0_col1, #T_f56bb_row0_col2, #T_f56bb_row0_col3, #T_f56bb_row0_col4, #T_f56bb_row0_col6, #T_f56bb_row0_col7, #T_f56bb_row0_col8, #T_f56bb_row0_col9, #T_f56bb_row0_col10, #T_f56bb_row0_col11, #T_f56bb_row0_col12, #T_f56bb_row0_col13, #T_f56bb_row0_col14, #T_f56bb_row0_col15, #T_f56bb_row0_col16, #T_f56bb_row1_col0, #T_f56bb_row1_col1, #T_f56bb_row1_col2, #T_f56bb_row1_col4, #T_f56bb_row1_col6, #T_f56bb_row1_col7, #T_f56bb_row1_col8, #T_f56bb_row1_col9, #T_f56bb_row1_col10, #T_f56bb_row1_col11, #T_f56bb_row1_col12, #T_f56bb_row1_col13, #T_f56bb_row1_col14, #T_f56bb_row1_col15, #T_f56bb_row1_col16, #T_f56bb_row2_col0, #T_f56bb_row2_col1, #T_f56bb_row2_col2, #T_f56bb_row2_col3, #T_f56bb_row2_col4, #T_f56bb_row2_col6, #T_f56bb_row2_col7, #T_f56bb_row2_col8, #T_f56bb_row2_col9, #T_f56bb_row2_col10, #T_f56bb_row2_col11, #T_f56bb_row2_col12, #T_f56bb_row2_col13, #T_f56bb_row2_col14, #T_f56bb_row2_col15, #T_f56bb_row2_col16, #T_f56bb_row3_col0, #T_f56bb_row3_col1, #T_f56bb_row3_col2, #T_f56bb_row3_col3, #T_f56bb_row3_col4, #T_f56bb_row3_col6, #T_f56bb_row3_col7, #T_f56bb_row3_col8, #T_f56bb_row3_col9, #T_f56bb_row3_col10, #T_f56bb_row3_col11, #T_f56bb_row3_col12, #T_f56bb_row3_col13, #T_f56bb_row3_col14, #T_f56bb_row3_col15, #T_f56bb_row3_col16, #T_f56bb_row4_col0, #T_f56bb_row4_col1, #T_f56bb_row4_col2, #T_f56bb_row4_col3, #T_f56bb_row4_col4, #T_f56bb_row4_col5, #T_f56bb_row4_col6, #T_f56bb_row4_col7, #T_f56bb_row4_col8, #T_f56bb_row4_col9, #T_f56bb_row4_col10, #T_f56bb_row4_col11, #T_f56bb_row4_col12, #T_f56bb_row4_col13, #T_f56bb_row4_col14, #T_f56bb_row4_col15, #T_f56bb_row4_col16, #T_f56bb_row5_col0, #T_f56bb_row5_col1, #T_f56bb_row5_col2, #T_f56bb_row5_col3, #T_f56bb_row5_col4, #T_f56bb_row5_col6, #T_f56bb_row5_col7, #T_f56bb_row5_col8, #T_f56bb_row5_col9, #T_f56bb_row5_col11, #T_f56bb_row5_col12, #T_f56bb_row5_col13, #T_f56bb_row5_col14, #T_f56bb_row5_col15, #T_f56bb_row5_col16, #T_f56bb_row6_col0, #T_f56bb_row6_col1, #T_f56bb_row6_col2, #T_f56bb_row6_col3, #T_f56bb_row6_col4, #T_f56bb_row6_col5, #T_f56bb_row6_col6, #T_f56bb_row6_col7, #T_f56bb_row6_col8, #T_f56bb_row6_col9, #T_f56bb_row6_col10, #T_f56bb_row6_col11, #T_f56bb_row6_col12, #T_f56bb_row6_col13, #T_f56bb_row6_col14, #T_f56bb_row6_col15, #T_f56bb_row6_col16, #T_f56bb_row7_col0, #T_f56bb_row7_col1, #T_f56bb_row7_col2, #T_f56bb_row7_col3, #T_f56bb_row7_col4, #T_f56bb_row7_col6, #T_f56bb_row7_col7, #T_f56bb_row7_col8, #T_f56bb_row7_col9, #T_f56bb_row7_col10, #T_f56bb_row7_col11, #T_f56bb_row7_col12, #T_f56bb_row7_col13, #T_f56bb_row7_col14, #T_f56bb_row7_col15, #T_f56bb_row7_col16, #T_f56bb_row8_col0, #T_f56bb_row8_col1, #T_f56bb_row8_col2, #T_f56bb_row8_col3, #T_f56bb_row8_col4, #T_f56bb_row8_col6, #T_f56bb_row8_col7, #T_f56bb_row8_col8, #T_f56bb_row8_col9, #T_f56bb_row8_col10, #T_f56bb_row8_col11, #T_f56bb_row8_col12, #T_f56bb_row8_col13, #T_f56bb_row8_col14, #T_f56bb_row8_col15, #T_f56bb_row8_col16, #T_f56bb_row9_col0, #T_f56bb_row9_col1, #T_f56bb_row9_col2, #T_f56bb_row9_col3, #T_f56bb_row9_col4, #T_f56bb_row9_col6, #T_f56bb_row9_col7, #T_f56bb_row9_col8, #T_f56bb_row9_col9, #T_f56bb_row9_col10, #T_f56bb_row9_col11, #T_f56bb_row9_col12, #T_f56bb_row9_col13, #T_f56bb_row9_col14, #T_f56bb_row9_col15, #T_f56bb_row9_col16, #T_f56bb_row10_col0, #T_f56bb_row10_col2, #T_f56bb_row10_col3, #T_f56bb_row10_col4, #T_f56bb_row10_col6, #T_f56bb_row10_col7, #T_f56bb_row10_col8, #T_f56bb_row10_col9, #T_f56bb_row10_col10, #T_f56bb_row10_col11, #T_f56bb_row10_col12, #T_f56bb_row10_col13, #T_f56bb_row10_col14, #T_f56bb_row10_col15, #T_f56bb_row10_col16, #T_f56bb_row11_col1, #T_f56bb_row11_col2, #T_f56bb_row11_col3, #T_f56bb_row11_col4, #T_f56bb_row11_col6, #T_f56bb_row11_col7, #T_f56bb_row11_col8, #T_f56bb_row11_col9, #T_f56bb_row11_col10, #T_f56bb_row11_col11, #T_f56bb_row11_col12, #T_f56bb_row11_col13, #T_f56bb_row11_col14, #T_f56bb_row11_col15, #T_f56bb_row11_col16, #T_f56bb_row12_col0, #T_f56bb_row12_col1, #T_f56bb_row12_col2, #T_f56bb_row12_col3, #T_ ...

# %% [markdown]
# # Exportations des fichiers

# %%
p9.to_excel('../src/p9_2020_cleaned.xlsx', index=False)
p9_log.to_excel('../src/p9_log_2020_cleaned.xlsx', index=True)
print("Exportation terminée")
# Out:
# Exportation terminée
