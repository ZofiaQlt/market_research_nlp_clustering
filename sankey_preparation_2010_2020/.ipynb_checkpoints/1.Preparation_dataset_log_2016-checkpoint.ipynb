# %% [markdown]
# # Chargement des librairies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mylib.fonction_exploration import exploration1, exploration2, exploration3, exploration4
from mylib.fonction_pk import test_pk
from mylib.fonction_merge import df_merge
from mylib.fonction_acp import display_circles, display_factorial_planes, display_scree_plot
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats
import seaborn as sns
from pandas_profiling import ProfileReport
import plotly.express as px
from IPython.display import display_html 

from sklearn.cluster import KMeans
from sklearn import decomposition
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn import preprocessing
#from scipy.cluster.hierarchy import dendrogram
from sklearn import metrics
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import AgglomerativeClustering
# to visualize the elbow curve and silhouette scores
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

print("Version numpy : " + np.__version__)
print("Version pandas : " + pd.__version__)

bold = "\033[1m"
red = "\033[31m"
end = "\033[0;0m"

chemin = '../src/df_2016_cleaned.csv'
# Out:
# Version numpy : 1.23.5
# Version pandas : 1.4.4

# %% [markdown]
# # Chargement du fichier nettoyé

# %%
p9 = pd.read_csv(chemin)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # Exploration

# %%
exploration1(p9)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd1ab" style='display:grid'>
#   <caption>__________ Head __________</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd1ab_level0_col0" class="col_heading level0 col0" >iso</th>
#       <th id="T_dd1ab_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_dd1ab_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_dd1ab_level0_col3" class="col_heading level0 col3" >Under-nourishment (%)</th>
#       <th id="T_dd1ab_level0_col4" class="col_heading level0 col4" >HDI</th>
#       <th id="T_dd1ab_level0_col5" class="col_heading level0 col5" >Peace_index</th>
#       <th id="T_dd1ab_level0_col6" class="col_heading level0 col6" >Vegetables disponibility (kg/cap/year)</th>
#       <th id="T_dd1ab_level0_col7" class="col_heading level0 col7" >Enough veg intake (> 91.25 kg/cap/year)</th>
#       <th id="T_dd1ab_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_dd1ab_level0_col9" class="col_heading level0 col9" >Exportations</th>
#       <th id="T_dd1ab_level0_col10" class="col_heading level0 col10" >Importations</th>
#       <th id="T_dd1ab_level0_col11" class="col_heading level0 col11" >Customs duration (h)</th>
#       <th id="T_dd1ab_level0_col12" class="col_heading level0 col12" >Customs tax (%)</th>
#       <th id="T_dd1ab_level0_col13" class="col_heading level0 col13" >Distance (km)</th>
#       <th id="T_dd1ab_level0_col14" class="col_heading level0 col14" >Gdp/cap</th>
#       <th id="T_dd1ab_level0_col15" class="col_heading level0 col15" >Population evolution (4y, %)</th>
#       <th id="T_dd1ab_level0_col16" class="col_heading level0 col16" >Trade balance (exp-imp)</th>
#       <th id="T_dd1ab_level0_col17" class="col_heading level0 col17" >Self-sufficiency (prod-dispo)</th>
#       <th id="T_dd1ab_level0_col18" class="col_heading level0 col18" >Market growth (2y, %)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd1ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd1ab_row0_col0" class="data row0 col0" >AFG</td>
#       <td id="T_dd1ab_row0_col1" class="data row0 col1" >Afghanistan</td>
#       <td id="T_dd1ab_row0_col2" class="data row0 col2" >34636207</td>
#       <td id="T_dd1ab_row0_col3" class="data row0 col3" >22.200000</td>
#       <td id="T_dd1ab_row0_col4" class="data row0 col4" >0.481000</td>
#       <td id="T_dd1ab_row0_col5" class="data row0 col5" >3.465000</td>
#       <td id="T_dd1ab_row0_col6" class="data row0 col6" >96.350000</td>
#       <td id="T_dd1ab_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_dd1ab_row0_col8" class="data row0 col8" >3640000000</td>
#       <td id="T_dd1ab_row0_col9" class="data row0 col9" >175000000</td>
#       <td id="T_dd1ab_row0_col10" class="data row0 col10" >598000000</td>
#       <td id="T_dd1ab_row0_col11" class="data row0 col11" >48.000000</td>
#       <td id="T_dd1ab_row0_col12" class="data row0 col12" >6.950000</td>
#       <td id="T_dd1ab_row0_col13" class="data row0 col13" >5500.665000</td>
#       <td id="T_dd1ab_row0_col14" class="data row0 col14" >2023.834656</td>
#       <td id="T_dd1ab_row0_col15" class="data row0 col15" >13.686281</td>
#       <td id="T_dd1ab_row0_col16" class="data row0 col16" >-423000000</td>
#       <td id="T_dd1ab_row0_col17" class="data row0 col17" >8.742339</td>
#       <td id="T_dd1ab_row0_col18" class="data row0 col18" >3.460208</td>
#     </tr>
#     <tr>
#       <th id="T_dd1ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd1ab_row1_col0" class="data row1 col0" >ZAF</td>
#       <td id="T_dd1ab_row1_col1" class="data row1 col1" >South Africa</td>
#       <td id="T_dd1ab_row1_col2" class="data row1 col2" >56422274</td>
#       <td id="T_dd1ab_row1_col3" class="data row1 col3" >5.400000</td>
#       <td id="T_dd1ab_row1_col4" class="data row1 col4" >0.719000</td>
#       <td id="T_dd1ab_row1_col5" class="data row1 col5" >2.293000</td>
#       <td id="T_dd1ab_row1_col6" class="data row1 col6" >169.430000</td>
#       <td id="T_dd1ab_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_dd1ab_row1_col8" class="data row1 col8" >12768000000</td>
#       <td id="T_dd1ab_row1_col9" class="data row1 col9" >2031000000</td>
#       <td id="T_dd1ab_row1_col10" class="data row1 col10" >3630000000</td>
#       <td id="T_dd1ab_row1_col11" class="data row1 col11" >92.000000</td>
#       <td id="T_dd1ab_row1_col12" class="data row1 col12" >6.480000</td>
#       <td id="T_dd1ab_row1_col13" class="data row1 col13" >8769.679000</td>
#       <td id="T_dd1ab_row1_col14" class="data row1 col14" >13696.163567</td>
#       <td id="T_dd1ab_row1_col15" class="data row1 col15" >6.166599</td>
#       <td id="T_dd1ab_row1_col16" class="data row1 col16" >-1599000000</td>
#       <td id="T_dd1ab_row1_col17" class="data row1 col17" >56.863609</td>
#       <td id="T_dd1ab_row1_col18" class="data row1 col18" >690.849673</td>
#     </tr>
#     <tr>
#       <th id="T_dd1ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd1ab_row2_col0" class="data row2 col0" >ALB</td>
#       <td id="T_dd1ab_row2_col1" class="data row2 col1" >Albania</td>
#       <td id="T_dd1ab_row2_col2" class="data row2 col2" >2876101</td>
#       <td id="T_dd1ab_row2_col3" class="data row2 col3" >4.700000</td>
#       <td id="T_dd1ab_row2_col4" class="data row2 col4" >0.798000</td>
#       <td id="T_dd1ab_row2_col5" class="data row2 col5" >1.881000</td>
#       <td id="T_dd1ab_row2_col6" class="data row2 col6" >340.580000</td>
#       <td id="T_dd1ab_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_dd1ab_row2_col8" class="data row2 col8" >1763000000</td>
#       <td id="T_dd1ab_row2_col9" class="data row2 col9" >125000000</td>
#       <td id="T_dd1ab_row2_col10" class="data row2 col10" >117000000</td>
#       <td id="T_dd1ab_row2_col11" class="data row2 col11" >9.000000</td>
#       <td id="T_dd1ab_row2_col12" class="data row2 col12" >1.440000</td>
#       <td id="T_dd1ab_row2_col13" class="data row2 col13" >1499.451000</td>
#       <td id="T_dd1ab_row2_col14" class="data row2 col14" >12082.742487</td>
#       <td id="T_dd1ab_row2_col15" class="data row2 col15" >-0.837815</td>
#       <td id="T_dd1ab_row2_col16" class="data row2 col16" >8000000</td>
#       <td id="T_dd1ab_row2_col17" class="data row2 col17" >272.402646</td>
#       <td id="T_dd1ab_row2_col18" class="data row2 col18" >28.571429</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_d9800" style='display:grid'>
#   <caption>__________ Tail __________</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9800_level0_col0" class="col_heading level0 col0" >iso</th>
#       <th id="T_d9800_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_d9800_level0_col2" class="col_heading level0 col2" >Population</th>
#       <th id="T_d9800_level0_col3" class="col_heading level0 col3" >Under-nourishment (%)</th>
#       <th id="T_d9800_level0_col4" class="col_heading level0 col4" >HDI</th>
#       <th id="T_d9800_level0_col5" class="col_heading level0 col5" >Peace_index</th>
#       <th id="T_d9800_level0_col6" class="col_heading level0 col6" >Vegetables disponibility (kg/cap/year)</th>
#       <th id="T_d9800_level0_col7" class="col_heading level0 col7" >Enough veg intake (> 91.25 kg/cap/year)</th>
#       <th id="T_d9800_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_d9800_level0_col9" class="col_heading level0 col9" >Exportations</th>
#       <th id="T_d9800_level0_col10" class="col_heading level0 col10" >Importations</th>
#       <th id="T_d9800_level0_col11" class="col_heading level0 col11" >Customs duration (h)</th>
#       <th id="T_d9800_level0_col12" class="col_heading level0 col12" >Customs tax (%)</th>
#       <th id="T_d9800_level0_col13" class="col_heading level0 col13" >Distance (km)</th>
#       <th id="T_d9800_level0_col14" class="col_heading level0 col14" >Gdp/cap</th>
#       <th id="T_d9800_level0_col15" class="col_heading level0 col15" >Population e

# %%
exploration2(p9)
# Out:
#                                         Nombre de valeurs totales  \
# iso                                                           144
# Country                                                       144
# Population                                                    144
# Under-nourishment (%)                                         144
# HDI                                                           144
# Peace_index                                                   144
# Vegetables disponibility (kg/cap/year)                        144
# Enough veg intake (> 91.25 kg/cap/year)                       144
# Production                                                    144
# Exportations                                                  144
# Importations                                                  144
# Customs duration (h)                                          144
# Customs tax (%)                                               144
# Distance (km)                                                 144
# Gdp/cap                                                       144
# Population evolution (4y, %)                                  144
# Trade balance (exp-imp)                                       144
# Self-sufficiency (prod-dispo)                                 144
# Market growth (2y, %)                                         144
#
#                                         Type des données Nombre de NaN  \
# iso                                               object             0
# Country                                           object             0
# Population                                         int64             0
# Under-nourishment (%)                            float64             0
# HDI                                              float64             0
# Peace_index                                      float64             0
# Vegetables disponibility (kg/cap/year)           float64             0
# Enough veg intake (> 91.25 kg/cap/year)            int64             0
# Production                                         int64             0
# Exportations                                       int64             0
# Importations                                       int64             0
# Customs duration (h)                             float64             0
# Customs tax (%)                                  float64             0
# Distance (km)                                    float64             0
# Gdp/cap                                          float64             0
# Population evolution (4y, %)                     float64             0
# Trade balance (exp-imp)                            int64             0
# Self-sufficiency (prod-dispo)                    float64             0
# Market growth (2y, %)                            float64             0
#
#                                         NaN en % Nombre de valeurs uniques  \
# iso                                         0.00                       144
# Country                                     0.00                       144
# Population                                  0.00                       144
# Under-nourishment (%)                       0.00                        80
# HDI                                         0.00                       122
# Peace_index                                 0.00                       138
# Vegetables disponibility (kg/cap/year)      0.00                       144
# Enough veg intake (> 91.25 kg/cap/year)     0.00                         2
# Production                                  0.00                       144
# Exportations                                0.00                       117
# Importations                                0.00                       138
# Customs duration (h)                        0.00                        96
# Customs tax (%)                             0.00                       116
# Distance (km)                               0.00                       144
# Gdp/cap                                     0.00                       144
# Population evolution (4y, %)                0.00                       144
# Trade balance (exp-imp)                     0.00                       144
# Self-sufficiency (prod-dispo)               0.00                       144
# Market growth (2y, %)                       0.00                       144
#
#                                         Valeurs uniques en%
# iso                                                  100.00
# Country                                              100.00
# Population                                           100.00
# Under-nourishment (%)                                 55.56
# HDI                                                   84.72
# Peace_index                                           95.83
# Vegetables disponibility (kg/cap/year)               100.00
# Enough veg intake (> 91.25 kg/cap/year)                1.39
# Production                                           100.00
# Exportations                                          81.25
# Importations                                          95.83
# Customs duration (h)                                  66.67
# Customs tax (%)                                       80.56
# Distance (km)                                        100.00
# Gdp/cap                                              100.00
# Population evolution (4y, %)                         100.00
# Trade balance (exp-imp)                              100.00
# Self-sufficiency (prod-dispo)                        100.00
# Market growth (2y, %)                                100.00

# %%
exploration3(p9)
# Out:
# ---------------------------------------
# Nombre de lignes et de colonnes (shape)
# ---------------------------------------
#
# (144, 19)
#
# --------------------------------------
# Affichage des NaN (isna().any(axis=1))
# --------------------------------------
#
# Empty DataFrame
# Columns: [iso, Country, Population, Under-nourishment (%), HDI, Peace_index, Vegetables disponibility (kg/cap/year), Enough veg intake (> 91.25 kg/cap/year), Production, Exportations, Importations, Customs duration (h), Customs tax (%), Distance (km), Gdp/cap, Population evolution (4y, %), Trade balance (exp-imp), Self-sufficiency (prod-dispo), Market growth (2y, %)]
# Index: []
#
# ---------------------------------------
# Nombre de doublons (duplicated().sum())
# ---------------------------------------
#
# 0
#
# -----------------------------------------------------
# Affichage des doublons (df[df.duplicated()].head(10))
# -----------------------------------------------------
#
# Empty DataFrame
# Columns: [iso, Country, Population, Under-nourishment (%), HDI, Peace_index, Vegetables disponibility (kg/cap/year), Enough veg intake (> 91.25 kg/cap/year), Production, Exportations, Importations, Customs duration (h), Customs tax (%), Distance (km), Gdp/cap, Population evolution (4y, %), Trade balance (exp-imp), Self-sufficiency (prod-dispo), Market growth (2y, %)]
# Index: []

# %%
exploration4(p9)
# Out:
#                                          count unique          top freq  \
# iso                                        144    144          AFG    1
# Country                                    144    144  Afghanistan    1
# Population                              144.00    NaN          NaN  NaN
# Under-nourishment (%)                   144.00    NaN          NaN  NaN
# HDI                                     144.00    NaN          NaN  NaN
# Peace_index                             144.00    NaN          NaN  NaN
# Vegetables disponibility (kg/cap/year)  144.00    NaN          NaN  NaN
# Enough veg intake (> 91.25 kg/cap/year) 144.00    NaN          NaN  NaN
# Production                              144.00    NaN          NaN  NaN
# Exportations                            144.00    NaN          NaN  NaN
# Importations                            144.00    NaN          NaN  NaN
# Customs duration (h)                    144.00    NaN          NaN  NaN
# Customs tax (%)                         144.00    NaN          NaN  NaN
# Distance (km)                           144.00    NaN          NaN  NaN
# Gdp/cap                                 144.00    NaN          NaN  NaN
# Population evolution (4y, %)            144.00    NaN          NaN  NaN
# Trade balance (exp-imp)                 144.00    NaN          NaN  NaN
# Self-sufficiency (prod-dispo)           144.00    NaN          NaN  NaN
# Market growth (2y, %)                   144.00    NaN          NaN  NaN
#
#                                                   mean            std  \
# iso                                                NaN            NaN
# Country                                            NaN            NaN
# Population                                 50268481.36   164367900.14
# Under-nourishment (%)                             9.25           9.46
# HDI                                               0.72           0.15
# Peace_index                                       2.02           0.44
# Vegetables disponibility (kg/cap/year)          197.71          94.31
# Enough veg intake (> 91.25 kg/cap/year)           0.94           0.23
# Production                              22137812500.00 96465112301.07
# Exportations                             2291208333.33  7186850409.56
# Importations                             2169430555.56  4875077275.56
# Customs duration (h)                             59.53          69.19
# Customs tax (%)                                   7.00           4.60
# Distance (km)                                  5502.72        3593.55
# Gdp/cap                                       18523.82       17081.11
# Population evolution (4y, %)                      6.01           5.89
# Trade balance (exp-imp)                   121777777.78  6652196338.96
# Self-sufficiency (prod-dispo)                   156.08         255.05
# Market growth (2y, %)                            26.70          97.84
#
#                                                     min           25%  \
# iso                                                 NaN           NaN
# Country                                             NaN           NaN
# Population                                    335439.00    4897737.50
# Under-nourishment (%)                              2.50          2.50
# HDI                                                0.38          0.59
# Peace_index                                        1.12          1.75
# Vegetables disponibility (kg/cap/year)            41.00        131.57
# Enough veg intake (> 91.25 kg/cap/year)            0.00          1.00
# Production                                  15000000.00 1052500000.00
# Exportations                                       0.00   17750000.00
# Importations                                 4000000.00  119500000.00
# Customs duration (h)                               0.00         11.44
# Customs tax (%)                                    1.23          2.58
# Distance (km)                                    408.96       2070.57
# Gdp/cap                                          932.41       4627.64
# Population evolution (4y, %)                      -5.26          2.03
# Trade balance (exp-imp)                 -30407000000.00 -751250000.00
# Self-sufficiency (prod-dispo)                   -134.49          6.51
# Market growth (2y, %)                            -44.55         -3.43
#
#                                                   50%            75%  \
# iso                                               NaN            NaN
# Country                                           NaN            NaN
# Population                                11261550.00    35357819.75
# Under-nourishment (%)                            5.80          13.03
# HDI                                              0.75           0.85
# Peace_index                                      2.01           2.24
# Vegetables disponibility (kg/cap/year)         171.78         252.18
# Enough veg intake (> 91.25 kg/cap/year)          1.00           1.00
# Production                              3636500000.00 12491250000.00
# Exportations                             140500000.00   789250000.00
# Importations                             473000000.00  1705000000.00
# Customs duration (h)                            48.00          78.50
# Customs tax (%)                                  5.34          10.89
# Distance (km)                                 5163.97        8469.27
# Gdp/cap                                      12941.32       27609.54
# Population evolution (4y, %)                     5.05           9.41
# Trade balance (exp-imp)                 -182500000.00    33750000.00
# Self-sufficiency (prod-dispo)                   62.19         216.26
# Market growth (2y, %)                            7.56          22.80
#
#                                                      max
# iso                                                  NaN
# Country                                              NaN
# Population                                 1387790000.00
# Under-nourishment (%)                              46.10
# HDI                                                 0.96
# Peace_index                                         3.46
# Vegetables disponibility (kg/cap/year)            455.52
# Enough veg intake (> 91.25 kg/cap/year)             1.00
# Production                              1031397000000.00
# Exportations                              67072000000.00
# Importations                              45047000000.00
# Customs duration (h)                              515.04
# Customs tax (%)                                    20.92
# Distance (km)                                   18894.29
# Gdp/cap                                         71498.60
# Population evolution (4y, %)                       38.17
# Trade balance (exp-imp)                   50935000000.00
# Self-sufficiency (prod-dispo)                    1278.55
# Market growth (2y, %)                             766.67

# %%
p9.sample()
# Out:
#     iso   Country  Population  Under-nourishment (%)  HDI  Peace_index  \
# 51  HND  Honduras     9460798                  13.80 0.62         2.29
#
#     Vegetables disponibility (kg/cap/year)  \
# 51                                  121.12
#
#     Enough veg intake (> 91.25 kg/cap/year)  Production  Exportations  \
# 51                                        1  1457000000     471000000
#
#     Importations  Customs duration (h)  Customs tax (%)  Distance (km)  \
# 51     730000000                108.00             4.32        8850.73
#
#     Gdp/cap  Population evolution (4y, %)  Trade balance (exp-imp)  \
# 51  5043.87                          7.60               -259000000
#
#     Self-sufficiency (prod-dispo)  Market growth (2y, %)
# 51                          32.88                  39.31

# %% [markdown]
# # Vérification des outliers en prévision de l'ACP

# %%
# on détermine les colonnes numériques
num = []
for i in p9.columns:
    if p9[i].dtypes == int or p9[i].dtypes == float:
        num.append(i)

# %% [markdown]
# ## Z-score

# %%
# on calcule le z-score sur toutes les variables numériques
for i in num:
    p9.sort_values(by=i, inplace=True)
    outlier_z = p9[stats.zscore(p9[i]) > 1.96]
    nb_outlier_z = len(outlier_z)
    print(bold + f"\n{i} : {nb_outlier_z} outliers \n\n" + end + f"{outlier_z[['Country', i]]} \n" + "-" * 50)
# Out:
# Population : 2 outliers
#
#    Country  Population
# 53   India  1338636340
# 26   China  1387790000
# --------------------------------------------------
#
# Under-nourishment (%) : 9 outliers
#
#               Country  Under-nourishment (%)
# 123              Chad                  28.50
# 84         Mozambique                  31.50
# 67            Lesotho                  32.00
# 107            Rwanda                  34.90
# 111  Congo, Dem. Rep.                  36.00
# 71            Liberia                  36.30
# 74         Madagascar                  41.60
# 50              Haiti                  43.20
# 136       Yemen, Rep.                  46.10
# --------------------------------------------------
#
# HDI : 0 outliers
#
# Empty DataFrame
# Columns: [Country, HDI]
# Index: []
# --------------------------------------------------
#
# Peace_index : 7 outliers
#
#                 Country  Peace_index
# 111    Congo, Dem. Rep.         3.08
# 41   Russian Federation         3.10
# 96             Pakistan         3.13
# 70                Libya         3.16
# 136         Yemen, Rep.         3.18
# 132             Ukraine         3.20
# 0           Afghanistan         3.46
# --------------------------------------------------
#
# Vegetables disponibility (kg/cap/year) : 10 outliers
#
#                     Country  Vegetables disponibility (kg/cap/year)
# 107                  Rwanda                                  385.97
# 89                  Nigeria                                  387.02
# 21                    Benin                                  387.18
# 76                   Malawi                                  396.76
# 15   Bosnia and Herzegovina                                  417.38
# 95               Uzbekistan                                  419.32
# 8                   Armenia                                  425.17
# 26                    China                                  436.81
# 44                    Ghana                                  444.61
# 111        Congo, Dem. Rep.                                  455.52
# --------------------------------------------------
#
# Enough veg intake (> 91.25 kg/cap/year) : 0 outliers
#
# Empty DataFrame
# Columns: [Country, Enough veg intake (> 91.25 kg/cap/year)]
# Index: []
# --------------------------------------------------
#
# Production : 3 outliers
#
#            Country     Production
# 53           India   219086000000
# 142  United States   474339000000
# 26           China  1031397000000
# --------------------------------------------------
#
# Exportations : 5 outliers
#
#            Country  Exportations
# 132        Ukraine   18038000000
# 17          Brazil   22611000000
# 7        Argentina   25895000000
# 125       Thailand   31261000000
# 142  United States   67072000000
# --------------------------------------------------
#
# Importations : 4 outliers
#
#            Country  Importations
# 81          Mexico   15414000000
# 142  United States   16137000000
# 61           Japan   18570000000
# 26           China   45047000000
# --------------------------------------------------
#
# Customs duration (h) : 6 outliers
#
#               Country  Customs duration (h)
# 23           Cameroon                202.00
# 32      Cote d'Ivoire                238.71
# 29        Congo, Rep.                276.00
# 134     Venezuela, RB                288.00
# 5              Angola                312.00
# 111  Congo, Dem. Rep.                515.04
# --------------------------------------------------
#
# Customs tax (%) : 6 outliers
#
#                 Country  Customs tax (%)
# 143            Ethiopia            17.87
# 123                Chad            18.16
# 42                Gabon            18.89
# 23             Cameroon            18.91
# 34             Djibouti            18.92
# 55   Iran, Islamic Rep.            20.92
# --------------------------------------------------
#
# Distance (km) : 4 outliers
#
#               Country  Distance (km)
# 126       Timor-Leste       13175.21
# 98   Papua New Guinea       14488.95
# 9           Australia       16513.02
# 91        New Zealand       18894.29
# --------------------------------------------------
#
# Gdp/cap : 9 outliers
#
#                   Country  Gdp/cap
# 33                Denmark 51976.01
# 100           Netherlands 52288.42
# 10                Austria 52684.02
# 57                Iceland 53480.40
# 142         United States 57866.74
# 90                 Norway 58939.91
# 119           Switzerland 68105.15
# 140  United Arab Emirates 68853.82
# 56                Ireland 71498.60
# --------------------------------------------------
#
# Population evolution (4y, %) : 4 outliers
#
#     Country  Population evolution (4y, %)
# 66   Kuwait                         19.25
# 69  Lebanon                         20.86
# 93     Oman                         24.39
# 62   Jordan                         38.17
# --------------------------------------------------
#
# Trade balance (exp-imp) : 5 outliers
#
#            Country  Trade balance (exp-imp)
# 132        Ukraine              17792000000
# 17          Brazil              18278000000
# 125       Thailand              23684000000
# 7        Argentina              25728000000
# 142  United States              50935000000
# --------------------------------------------------
#
# Self-sufficiency (prod-dispo) : 6 outliers
#
#            Country  Self-sufficiency (prod-dispo)
# 7        Argentina                         942.11
# 52         Hungary                         961.97
# 132        Ukraine                        1031.73
# 99        Paraguay                        1099.81
# 114         Serbia                        1143.76
# 142  United States                        1278.55
# --------------------------------------------------
#
# Market growth (2y, %) : 4 outliers
#
#           Country  Market growth (2y, %)
# 125      Thailand                 241.31
# 85        Myanmar                 377.27
# 1    South Africa                 690.85
# 76         Malawi                 766.67
# --------------------------------------------------

# %% [markdown]
# ## Log

# %%
p9_log = p9.copy()
p9_log = p9_log.set_index(['Country'])
p9_log = p9_log[num]
p9_log.sample()
# Out:
#           Population  Under-nourishment (%)  HDI  Peace_index  \
# Country
# Eswatini     1142524                  13.00 0.59         2.03
#
#           Vegetables disponibility (kg/cap/year)  \
# Country
# Eswatini                                  113.77
#
#           Enough veg intake (> 91.25 kg/cap/year)  Production  Exportations  \
# Country
# Eswatini                                        1    60000000       1000000
#
#           Importations  Customs duration (h)  Customs tax (%)  Distance (km)  \
# Country
# Eswatini     159000000                  2.72             4.40        8628.11
#
#           Gdp/cap  Population evolution (4y, %)  Trade balance (exp-imp)  \
# Country
# Eswatini  8488.45                          2.80               -158000000
#
#           Self-sufficiency (prod-dispo)  Market growth (2y, %)
# Country
# Eswatini                         -61.25                  26.19

# %% [markdown]
# ### Graphiques de distribution

# %%
f, a = plt.subplots(6, 3, figsize=(20,40))
a = a.flatten()
for i, col in enumerate(p9_log.columns):
    sns.distplot(p9_log[col], ax=a[i], kde= True).set_title('Skew: {:.2f}'.format(p9_log[col].skew()))
plt.show()

# %% [raw]
# #Plot a Histogram of the data
# #fig, axes = plt.subplots(5, 3, figsize=(25, 20))
# for i in p9_log.columns:
#     ax = sns.distplot(p9_log[i], kde=True)
# #ax.set(xlabel= ‘Garage Area (ft²)’, ylabel=’Counts’, title=’Frequency of Garage Sizes (ft²)’)
#     plt.show()

# %% [markdown]
# ### Calcul de Skew et Kurtosis

# %%
#Calculating Skew and Kurtosis 
for i in p9_log.columns:
    kurtosis = round((stats.kurtosis(p9_log[i])), ndigits=2)
    skew = round((stats.skew(p9_log[i])), ndigits=2)
    #print("\nkurtosis :", i, kurtosis) 
    #print("skew", i, skew, "\n")
    print("\n" + "-" * 50 + bold + f"\n{i} : kurtosis {kurtosis}" + end)
    print(bold + f"{i} : skew {skew} \n" + end)
#Interpreting Kurtosis
    if  -0.5 < kurtosis < 0.5:
        print (f'A kurtosis of {kurtosis} means the distribution is approximately normal sometimes called mesokurtic distributions')
    elif kurtosis <= -0.5: 
        print (f'A kurtosis of {kurtosis} means the distribution is light-tailed (negative) sometimes called a platykurtic distributions')
    elif kurtosis >= 0.5:
        print (f'A kurtosis of {kurtosis} means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution')
#Interpreting Skewness
    if -0.5 < skew < 0.5:
        print (f'A skew of {skew} means the distribution is approx. symmetric')
    elif  -1 < skew < -0.5 or 0.5 < skew < 1.0:
        print (f'A skew of {skew} means the distribution is moderately skewed')
    else:
        print (f'A skew of {skew} means the distribution is highly skewed')
# Out:
# --------------------------------------------------
# Population : kurtosis 54.55
# Population : skew 7.22
#
# A kurtosis of 54.55 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 7.22 means the distribution is highly skewed
#
# --------------------------------------------------
# Under-nourishment (%) : kurtosis 3.11
# Under-nourishment (%) : skew 1.84
#
# A kurtosis of 3.11 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.84 means the distribution is highly skewed
#
# --------------------------------------------------
# HDI : kurtosis -1.01
# HDI : skew -0.32
#
# A kurtosis of -1.01 means the distribution is light-tailed (negative) sometimes called a platykurtic distributions
# A skew of -0.32 means the distribution is approx. symmetric
#
# --------------------------------------------------
# Peace_index : kurtosis 0.79
# Peace_index : skew 0.64
#
# A kurtosis of 0.79 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 0.64 means the distribution is moderately skewed
#
# --------------------------------------------------
# Vegetables disponibility (kg/cap/year) : kurtosis 0.09
# Vegetables disponibility (kg/cap/year) : skew 0.87
#
# A kurtosis of 0.09 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.87 means the distribution is moderately skewed
#
# --------------------------------------------------
# Enough veg intake (> 91.25 kg/cap/year) : kurtosis 13.06
# Enough veg intake (> 91.25 kg/cap/year) : skew -3.88
#
# A kurtosis of 13.06 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of -3.88 means the distribution is highly skewed
#
# --------------------------------------------------
# Production : kurtosis 84.92
# Production : skew 8.83
#
# A kurtosis of 84.92 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 8.83 means the distribution is highly skewed
#
# --------------------------------------------------
# Exportations : kurtosis 46.92
# Exportations : skew 6.16
#
# A kurtosis of 46.92 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 6.16 means the distribution is highly skewed
#
# --------------------------------------------------
# Importations : kurtosis 41.24
# Importations : skew 5.53
#
# A kurtosis of 41.24 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 5.53 means the distribution is highly skewed
#
# --------------------------------------------------
# Customs duration (h) : kurtosis 13.79
# Customs duration (h) : skew 3.0
#
# A kurtosis of 13.79 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 3.0 means the distribution is highly skewed
#
# --------------------------------------------------
# Customs tax (%) : kurtosis -0.14
# Customs tax (%) : skew 0.81
#
# A kurtosis of -0.14 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.81 means the distribution is moderately skewed
#
# --------------------------------------------------
# Distance (km) : kurtosis 0.44
# Distance (km) : skew 0.68
#
# A kurtosis of 0.44 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 0.68 means the distribution is moderately skewed
#
# --------------------------------------------------
# Gdp/cap : kurtosis 0.44
# Gdp/cap : skew 1.13
#
# A kurtosis of 0.44 means the distribution is approximately normal sometimes called mesokurtic distributions
# A skew of 1.13 means the distribution is highly skewed
#
# --------------------------------------------------
# Population evolution (4y, %) : kurtosis 5.36
# Population evolution (4y, %) : skew 1.44
#
# A kurtosis of 5.36 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 1.44 means the distribution is highly skewed
#
# --------------------------------------------------
# Trade balance (exp-imp) : kurtosis 28.04
# Trade balance (exp-imp) : skew 3.21
#
# A kurtosis of 28.04 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 3.21 means the distribution is highly skewed
#
# --------------------------------------------------
# Self-sufficiency (prod-dispo) : kurtosis 5.46
# Self-sufficiency (prod-dispo) : skew 2.23
#
# A kurtosis of 5.46 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 2.23 means the distribution is highly skewed
#
# --------------------------------------------------
# Market growth (2y, %) : kurtosis 36.42
# Market growth (2y, %) : skew 5.66
#
# A kurtosis of 36.42 means the distribution is heavy-tailed (positive) sometimes called a leptokurtic distribution
# A skew of 5.66 means the distribution is highly skewed

# %% [markdown]
# ### Test de normalité

# %%
# calculate
for i in p9_log.columns:
    stat, p = stats.normaltest(p9_log[i])
    print (bold + f'{i}' + end + f': \nStatistic={stat}, p={p}')
   # print ('--'*25) 

# interpret
    alpha = 0.05
    if p > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
        print ('--'*25) 
    else:
        print('Sample does not look Gaussian (reject H0)')
        print ('--'*25)
# Out:
# Population:
# Statistic=234.37110428364997, p=1.2792674390701418e-51
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Under-nourishment (%):
# Statistic=60.65104840827386, p=6.757595272037096e-14
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# HDI:
# Statistic=26.37423616236231, p=1.8745947013622414e-06
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Peace_index:
# Statistic=12.512289839013077, p=0.0019186280234180172
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Vegetables disponibility (kg/cap/year):
# Statistic=15.673064591621543, p=0.00039503653810450163
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Enough veg intake (> 91.25 kg/cap/year):
# Statistic=141.07851126945638, p=2.3184114888664732e-31
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Production:
# Statistic=266.6888053584953, p=1.2281791594575605e-58
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Exportations:
# Statistic=213.91975645908673, p=3.5311413283862642e-47
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Importations:
# Statistic=199.90466946628402, p=3.901688306623389e-44
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Customs duration (h):
# Statistic=121.35673780220057, p=4.443438926923066e-27
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Customs tax (%):
# Statistic=13.86103504459034, p=0.0009774948620873706
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Distance (km):
# Statistic=11.696665588652504, p=0.0028847045469771607
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Gdp/cap:
# Statistic=24.635060347560547, p=4.472646914123538e-06
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Population evolution (4y, %):
# Statistic=57.57671392295755, p=3.143224699933779e-13
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Trade balance (exp-imp):
# Statistic=142.49563871037535, p=1.1414718516876577e-31
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Self-sufficiency (prod-dispo):
# Statistic=81.3040898993133, p=2.2133046695595565e-18
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------
# Market growth (2y, %):
# Statistic=199.67188524295028, p=4.3832982681535137e-44
# Sample does not look Gaussian (reject H0)
# --------------------------------------------------

# %%
#pip install outliers

# %%
#import numpy as np
#from OUTLIERS import smirnov_grubbs as grubbs

#grubbs.max_test(p9.Population, alpha=.01)

# %% [markdown]
# ### Mise en log des colonnes éligibles

# %%
p9.columns
# Out:
# Index(['iso', 'Country', 'Population', 'Under-nourishment (%)', 'HDI',
#        'Peace_index', 'Vegetables disponibility (kg/cap/year)',
#        'Enough veg intake (> 91.25 kg/cap/year)', 'Production', 'Exportations',
#        'Importations', 'Customs duration (h)', 'Customs tax (%)',
#        'Distance (km)', 'Gdp/cap', 'Population evolution (4y, %)',
#        'Trade balance (exp-imp)', 'Self-sufficiency (prod-dispo)',
#        'Market growth (2y, %)'],
#       dtype='object')

# %%
# Data varies in several magnitudes and has both positive, zero and negative numbers  
# log modulus transform 
log_columns = ['Population', 'Under-nourishment (%)', 'Peace_index', 'Vegetables disponibility (kg/cap/year)',
              'Production', 'Exportations', 'Importations', 'Customs duration (h)', 'Customs tax (%)',
               'Distance (km)', 'Gdp/cap', 'Trade balance (exp-imp)', 'Population evolution (4y, %)',
               'Self-sufficiency (prod-dispo)', 'Market growth (2y, %)']
for i in log_columns:
    p9_log[i] = np.sign(p9_log[i])*(np.log10(np.abs(p9_log[i])+1))
    
p9_log
# Out:
#                     Population  Under-nourishment (%)  HDI  Peace_index  \
# Country
# Ecuador                   7.22                   1.03 0.76         0.48
# Kazakhstan                7.25                   0.54 0.81         0.48
# Russian Federation        8.16                   0.54 0.83         0.61
# Uruguay                   6.53                   0.54 0.81         0.43
# Turkiye                   7.91                   0.54 0.82         0.56
# ...                        ...                    ...  ...          ...
# Ethiopia                  8.02                   1.19 0.47         0.51
# Thailand                  7.85                   0.93 0.79         0.52
# Myanmar                   7.72                   0.65 0.57         0.51
# South Africa              7.75                   0.81 0.72         0.52
# Malawi                    7.24                   1.23 0.50         0.45
#
#                     Vegetables disponibility (kg/cap/year)  \
# Country
# Ecuador                                               2.00
# Kazakhstan                                            2.53
# Russian Federation                                    2.29
# Uruguay                                               2.14
# Turkiye                                               2.51
# ...                                                    ...
# Ethiopia                                              2.05
# Thailand                                              1.76
# Myanmar                                               2.09
# South Africa                                          2.23
# Malawi                                                2.60
#
#                     Enough veg intake (> 91.25 kg/cap/year)  Production  \
# Country
# Ecuador                                                   1        9.33
# Kazakhstan                                                1       10.03
# Russian Federation                                        1       10.75
# Uruguay                                                   1        8.93
# Turkiye                                                   1       10.63
# ...                                                     ...         ...
# Ethiopia                                                  1       10.22
# Thailand                                                  0       10.59
# Myanmar                                                   1       10.09
# South Africa                                              1       10.11
# Malawi                                                    1       10.16
#
#                     Exportations  Importations  Customs duration (h)  \
# Country
# Ecuador                     8.04          8.26                  1.99
# Kazakhstan                  8.36          8.62                  2.13
# Russian Federation          9.83          9.38                  1.86
# Uruguay                     6.00          8.32                  1.99
# Turkiye                     9.47          9.08                  1.03
# ...                          ...           ...                   ...
# Ethiopia                    8.54          8.26                  1.76
# Thailand                   10.50          9.88                  1.72
# Myanmar                     9.21          8.02                  2.16
# South Africa                9.31          9.56                  1.97
# Malawi                      7.69          8.53                  1.94
#
#                     Customs tax (%)  Distance (km)  Gdp/cap  \
# Country
# Ecuador                        1.08           3.98     4.04
# Kazakhstan                     0.79           3.70     4.38
# Russian Federation             0.80           3.53     4.38
# Uruguay                        1.04           4.03     4.35
# Turkiye                        0.54           3.39     4.42
# ...                             ...            ...      ...
# Ethiopia                       1.28           3.73     3.27
# Thailand                       0.95           3.98     4.21
# Myanmar                        0.49           3.94     3.62
# South Africa                   0.87           3.94     4.14
# Malawi                         1.01           3.87     3.16
#
#                     Population evolution (4y, %)  Trade balance (exp-imp)  \
# Country
# Ecuador                                     0.86                    -7.86
# Kazakhstan                                  0.84                    -8.27
# Russian Federation                          0.25                     9.64
# Uruguay                                     0.36                    -8.32
# Turkiye                                     0.94                     9.24
# ...                                          ...                      ...
# Ethiopia                                    1.10                     8.22
# Thailand                                    0.49                    10.37
# Myanmar                                     0.64                     9.18
# South Africa                                0.86                    -9.20
# Malawi                                      1.10                    -8.46
#
#                     Self-sufficiency (prod-dispo)  Market growth (2y, %)
# Country
# Ecuador                                      1.52                  -1.66
# Kazakhstan                                   2.41                  -1.65
# Russian Federation                           2.28                  -1.64
# Uruguay                                      2.06                  -1.64
# Turkiye                                      2.31                  -1.62
# ...                                           ...                    ...
# Ethiopia                                     1.70                   2.25
# Thailand                                     2.69                   2.38
# Myanmar                                      2.08                   2.58
# South Africa                                 1.76                   2.84
# Malawi                                       2.65                   2.89
#
# [144 rows x 17 columns]

# %% [markdown]
# ## **Boxplots**

# %%
# création boxplots
fig=plt.figure(figsize=(25,15))
p9_log.boxplot(vert=False)
plt.yticks(size=20)
plt.show()

# %%
#pd.options.display.max_rows = None

# %% [markdown]
# # Vérification des corrélations

# %% [markdown]
# <span style="color:red">**Les distributions des variables n'étant pas toutes normales, nous allons utiliser le test de Spearman pour avoir un aperçu des corrélations**</span>

# %% [markdown]
# ## Corrélation de Spearman

# %%
corr = p9_log.corr(method='spearman')
#corr

# %%
plt.figure(figsize=(20,20))
sns.heatmap(p9_log.corr(method='spearman'), annot=True, annot_kws={"size": 14}, fmt=".2f")
plt.xticks(size=15)
plt.yticks(size=15)
plt.title("\nCorrelations on all numeric features\n", size=30, fontweight='bold' )
plt.show()

# %%
# Beaucoup d'informations, on va visualiser les corrélations les plus élevées
plt.figure(figsize=(20, 20))
sns.heatmap(np.round(corr, 2)[(corr >= 0.4) | (corr <= -0.4)], 
            vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 15}, square=True)
plt.xticks(size=15)
plt.yticks(size=15)
plt.title("\nHighest correlations\n", size=25, fontweight='bold' )
;
# Out:
# ''

# %% [markdown]
# # Visionnage du DataFrame final (log) avant analyse

# %%
cell_hover = {
    "selector": "td:hover",
    "props": [("background-color", "#FFFFE0")]
}
index_names = {
    "selector": ".index_name",
    "props": "background-color: #DC7633; font-style: italic; color: white; font-weight:normal;"
}
headers = {
    "selector": "th:not(.index_name)",
    "props": "background-color: #DC7633; color: white; text-align: center"
}

properties = {"border": "1px solid black", "width": "90px", "text-align": "center"}

styles = [dict(selector="caption",
                       props=[("text-align", "center"),
                              ("font-size", "150%"),
                              ("color", 'black')])]

p9_log.head(50).style.format(precision=2).highlight_max(axis=0, props='color:white; font-weight:bold; background-color:darkblue;').set_table_styles(
    styles, [cell_hover, index_names, headers]).set_properties(**properties).set_caption('Log DataFrame')

#p9_log.style.set_sticky(axis='index')
#p9_log.style.set_table_styles([cell_hover, index_names, headers])
#cm = sns.light_palette("orange", as_cmap=True)
#p9_log.style.background_gradient(cmap=cm)

#p9_log.style.highlight_max(axis=0, props='color:white; font-weight:bold; background-color:darkblue;')
# Out:
# <style type="text/css">
# #T_29de7 caption {
#   text-align: center;
#   font-size: 150%;
#   color: black;
# }
# #T_29de7_row0_col0, #T_29de7_row0_col1, #T_29de7_row0_col2, #T_29de7_row0_col3, #T_29de7_row0_col4, #T_29de7_row0_col6, #T_29de7_row0_col7, #T_29de7_row0_col8, #T_29de7_row0_col9, #T_29de7_row0_col10, #T_29de7_row0_col11, #T_29de7_row0_col12, #T_29de7_row0_col13, #T_29de7_row0_col14, #T_29de7_row0_col15, #T_29de7_row0_col16, #T_29de7_row1_col0, #T_29de7_row1_col1, #T_29de7_row1_col2, #T_29de7_row1_col3, #T_29de7_row1_col4, #T_29de7_row1_col6, #T_29de7_row1_col7, #T_29de7_row1_col8, #T_29de7_row1_col9, #T_29de7_row1_col10, #T_29de7_row1_col11, #T_29de7_row1_col12, #T_29de7_row1_col13, #T_29de7_row1_col14, #T_29de7_row1_col15, #T_29de7_row1_col16, #T_29de7_row2_col0, #T_29de7_row2_col1, #T_29de7_row2_col2, #T_29de7_row2_col3, #T_29de7_row2_col4, #T_29de7_row2_col6, #T_29de7_row2_col7, #T_29de7_row2_col8, #T_29de7_row2_col9, #T_29de7_row2_col10, #T_29de7_row2_col11, #T_29de7_row2_col12, #T_29de7_row2_col13, #T_29de7_row2_col14, #T_29de7_row2_col15, #T_29de7_row2_col16, #T_29de7_row3_col0, #T_29de7_row3_col1, #T_29de7_row3_col2, #T_29de7_row3_col3, #T_29de7_row3_col4, #T_29de7_row3_col6, #T_29de7_row3_col7, #T_29de7_row3_col8, #T_29de7_row3_col9, #T_29de7_row3_col10, #T_29de7_row3_col11, #T_29de7_row3_col12, #T_29de7_row3_col13, #T_29de7_row3_col14, #T_29de7_row3_col15, #T_29de7_row3_col16, #T_29de7_row4_col0, #T_29de7_row4_col1, #T_29de7_row4_col2, #T_29de7_row4_col3, #T_29de7_row4_col4, #T_29de7_row4_col6, #T_29de7_row4_col7, #T_29de7_row4_col8, #T_29de7_row4_col9, #T_29de7_row4_col10, #T_29de7_row4_col11, #T_29de7_row4_col12, #T_29de7_row4_col13, #T_29de7_row4_col14, #T_29de7_row4_col15, #T_29de7_row4_col16, #T_29de7_row5_col0, #T_29de7_row5_col2, #T_29de7_row5_col3, #T_29de7_row5_col4, #T_29de7_row5_col5, #T_29de7_row5_col6, #T_29de7_row5_col7, #T_29de7_row5_col8, #T_29de7_row5_col9, #T_29de7_row5_col10, #T_29de7_row5_col11, #T_29de7_row5_col12, #T_29de7_row5_col13, #T_29de7_row5_col14, #T_29de7_row5_col15, #T_29de7_row5_col16, #T_29de7_row6_col0, #T_29de7_row6_col1, #T_29de7_row6_col2, #T_29de7_row6_col3, #T_29de7_row6_col4, #T_29de7_row6_col6, #T_29de7_row6_col7, #T_29de7_row6_col8, #T_29de7_row6_col9, #T_29de7_row6_col10, #T_29de7_row6_col11, #T_29de7_row6_col12, #T_29de7_row6_col13, #T_29de7_row6_col14, #T_29de7_row6_col15, #T_29de7_row6_col16, #T_29de7_row7_col0, #T_29de7_row7_col1, #T_29de7_row7_col2, #T_29de7_row7_col3, #T_29de7_row7_col4, #T_29de7_row7_col6, #T_29de7_row7_col7, #T_29de7_row7_col8, #T_29de7_row7_col9, #T_29de7_row7_col10, #T_29de7_row7_col11, #T_29de7_row7_col12, #T_29de7_row7_col13, #T_29de7_row7_col14, #T_29de7_row7_col15, #T_29de7_row7_col16, #T_29de7_row8_col0, #T_29de7_row8_col1, #T_29de7_row8_col2, #T_29de7_row8_col3, #T_29de7_row8_col4, #T_29de7_row8_col6, #T_29de7_row8_col7, #T_29de7_row8_col8, #T_29de7_row8_col9, #T_29de7_row8_col10, #T_29de7_row8_col11, #T_29de7_row8_col12, #T_29de7_row8_col13, #T_29de7_row8_col14, #T_29de7_row8_col15, #T_29de7_row8_col16, #T_29de7_row9_col0, #T_29de7_row9_col1, #T_29de7_row9_col2, #T_29de7_row9_col3, #T_29de7_row9_col4, #T_29de7_row9_col6, #T_29de7_row9_col7, #T_29de7_row9_col8, #T_29de7_row9_col9, #T_29de7_row9_col10, #T_29de7_row9_col11, #T_29de7_row9_col12, #T_29de7_row9_col13, #T_29de7_row9_col14, #T_29de7_row9_col15, #T_29de7_row9_col16, #T_29de7_row10_col0, #T_29de7_row10_col1, #T_29de7_row10_col2, #T_29de7_row10_col3, #T_29de7_row10_col4, #T_29de7_row10_col6, #T_29de7_row10_col7, #T_29de7_row10_col8, #T_29de7_row10_col9, #T_29de7_row10_col10, #T_29de7_row10_col11, #T_29de7_row10_col12, #T_29de7_row10_col13, #T_29de7_row10_col14, #T_29de7_row10_col15, #T_29de7_row10_col16, #T_29de7_row11_col0, #T_29de7_row11_col1, #T_29de7_row11_col2, #T_29de7_row11_col4, #T_29de7_row11_col6, #T_29de7_row11_col8, #T_29de7_row11_col9, #T_29de7_row11_col10, #T_29de7_row11_col11, #T_29de7_row11_col12, #T_29de7_row11_col13, #T_29de7_row11_col15, #T_29de7_row11_col16, #T_29de7_row12_col0, #T_29de7_row12_col1, #T_29de7_row12_col2, #T_29de7_row12_col3, #T_29de7_row12_col4, #T_ ...

# %% [markdown]
# # Exportations des fichiers

# %%
p9.to_excel('../src/p9_2016_cleaned.xlsx', index=False)
p9_log.to_excel('../src/p9_log_2016_cleaned.xlsx', index=True)
print("Exportation terminée")
# Out:
# Exportation terminée
